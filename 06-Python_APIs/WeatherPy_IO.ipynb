# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Generate Cities List

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime


now = datetime.datetime.now()

# %%
# Import API key
from api_keys import api_key

# %%
# Output File (CSV)
citi_list = pd.read_csv("worldcities.csv")

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Choose a random sample of 100 cities
random_cities = citi_list.sample(n=700)

# %%
#view dataframe of random cities
random_cities.head()
# Out:
#              city   city_ascii      lat       lng        country iso2 iso3  \
# 6100      Ulanhot      Ulanhot  46.0800  122.0800          China   CN  CHN
# 9454      Tarboro      Tarboro  35.9046  -77.5562  United States   US  USA
# 27        Partesh      Partesh  42.4019   21.4336         Kosovo   XK  XKS
# 9415  Gibsonville  Gibsonville  36.0989  -79.5425  United States   US  USA
# 8175   Winchester   Winchester  39.1734  -78.1745  United States   US  USA
#
#           admin_name capital  population          id
# 6100  Inner Mongolia     NaN    241894.0  1156182060
# 9454  North Carolina     NaN     13080.0  1840016177
# 27           Partesh   admin         NaN  1901909986
# 9415  North Carolina     NaN      7029.0  1840016137
# 8175        Virginia     NaN     72928.0  1840001623

# %%
#create a series of cities
citi_search_list = random_cities.city

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create a series of cities
city_search_list = random_cities.city

# %%
#create several lists to hold raw data
name = []
clouds = []
date = []
humidity = []
temp_max = []
wind_speed = []

#log the length of the series
list_len = len(city_search_list)

#specify the base url
url = "http://api.openweathermap.org/data/2.5/weather?"

#set the measurement system
units = "imperial"

#initialize a variable for the record count
record_cnt = 1

#create a loop to get the information for all the cities and add them to the lists
#also add error handling
for city in city_search_list:
    print(f"Processing Record {record_cnt} of {list_len} | {city}")
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    response = requests.get(query_url).json()
    
    try:
        name.append(response["name"].lower())
    except KeyError:
        print("key is missing")
        
    try:
        clouds.append(response["clouds"]["all"])
    except KeyError:
        print("key is missing")
            
    try:
        date.append(response["dt"])
    except KeyError:
        print("key is missing")
                
    try:
        humidity.append(response["main"]["humidity"])
    except KeyError:
        print("key is missing")
                    
    try:
        temp_max.append(response["main"]["temp_max"])
    except KeyError:
        print("key is missing")
                        
    try:
        wind_speed.append(response["wind"]["speed"])
    except KeyError:
        print("key is missing")
        
    #iterate the record count on each loop
    record_cnt = record_cnt + 1
# Out:
# Processing Record 1 of 1200 | Gladstone
# Processing Record 2 of 1200 | Overland Park
# Processing Record 3 of 1200 | Bolgatanga
# Processing Record 4 of 1200 | Fargo
# Processing Record 5 of 1200 | Kon Tum
# Processing Record 6 of 1200 | Bakersfield
# Processing Record 7 of 1200 | Aurora
# Processing Record 8 of 1200 | Termiz
# Processing Record 9 of 1200 | Pori
# Processing Record 10 of 1200 | Allanmyo
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 11 of 1200 | Quba
# Processing Record 12 of 1200 | Destrnik
# Processing Record 13 of 1200 | Yumbe
# Processing Record 14 of 1200 | Borgarnes
# Processing Record 15 of 1200 | Palisades Park
# Processing Record 16 of 1200 | Inukjuak
# Processing Record 17 of 1200 | Makiyivka
# Processing Record 18 of 1200 | Tikhoretsk
# Processing Record 19 of 1200 | Glens Falls
# Processing Record 20 of 1200 | San Salvador
# Processing Record 21 of 1200 | Morganfield
# Processing Record 22 of 1200 | Severomorsk
# Processing Record 23 of 1200 | Gardena
# Processing Record 24 of 1200 | Nepalganj
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 25 of 1200 | Gulu
# Processing Record 26 of 1200 | Somers Point
# Processing Record 27 of 1200 | Kerewan
# Processing Record 28 of 1200 | Damascus
# Processing Record 29 of 1200 | Dagda
# Processing Record 30 of 1200 | Rosario
# Processing Record 31 of 1200 | Red Deer
# Processing Record 32 of 1200 | Fukui
# Processing Record 33 of 1200 | Mufulira
# Processing Record 34 of 1200 | Columbia
# Processing Record 35 of 1200 | Ntcheu
# Processing Record 36 of 1200 | Ancona
# Processing Record 37 of 1200 | Hudson Falls
# Processing Record 38 of 1200 | Camocim
# Processing Record 39 of 1200 | Dzaoudzi
# Processing Record 40 of 1200 | Eureka
# Processing Record 41 of 1200 | Smithfield
# Processing Record 42 of 1200 | Aldan
# Processing Record 43 of 1200 | Jaguaquara
# Processing Record 44 of 1200 | Mazowe
# Processing Record 45 of 1200 | Kwale
# Processing Record 46 of 1200 | Santa Monica
# Processing Record 47 of 1200 | Soroti
# Processing Record 48 of 1200 | Saint Marys
# Processing Record 49 of 1200 | Trzin
# Processing Record 50 of 1200 | Manchester
# Processing Record 51 of 1200 | Ordu
# Processing Record 52 of 1200 | Kansk
# Processing Record 53 of 1200 | Bay Minette
# Processing Record 54 of 1200 | Koani
# Processing Record 55 of 1200 | Sumbe
# Processing Record 56 of 1200 | New Brighton
# Processing Record 57 of 1200 | Buenos Aires
# Processing Record 58 of 1200 | Elwood
# Processing Record 59 of 1200 | Virginia Beach
# Processing Record 60 of 1200 | Delčevo
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 61 of 1200 | Sauk Rapids
# Processing Record 62 of 1200 | Signal Hill
# Processing Record 63 of 1200 | Huntsville
# Processing Record 64 of 1200 | Bromley
# Processing Record 65 of 1200 | Xuchang
# Processing Record 66 of 1200 | Loikaw
# Processing Record 67 of 1200 | Alor Setar
# Processing Record 68 of 1200 | Lenexa
# Processing Record 69 of 1200 | Demir Kapija
# Processing Record 70 of 1200 | Sopore
# Processing Record 71 of 1200 | Šentrupert
# Processing Record 72 of 1200 | Deming
# Processing Record 73 of 1200 | Tirupati
# Processing Record 74 of 1200 | Sugar Land
# Processing Record 75 of 1200 | Johnson City
# Processing Record 76 of 1200 | Ujungpandang
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 77 of 1200 | Mendi
# Processing Record 78 of 1200 | Germantown
# Processing Record 79 of 1200 | Maumelle
# Processing Record 80 of 1200 | Brooklyn Park
# Processing Record 81 of 1200 | Laurium
# Processing Record 82 of 1200 | Glen Ellyn
# Processing Record 83 of 1200 | České Budějovice
# Processing Record 84 of 1200 | Buford
# Processing Record 85 of 1200 | Bulgan
# Processing Record 86 of 1200 | Lisbon
# Processing Record 87 of 1200 | Prospect Park
# Processing Record 88 of 1200 | Dolton
# Processing Record 89 of 1200 | Upper Hutt
# Processing Record 90 of 1200 | Dearborn Heights
# Processing Record 91 of 1200 | Nizhnekamsk
# Processing Record 92 of 1200 | Belfast
# Processing Record 93 of 1200 | Williamsville
# Processing Record 94 of 1200 | Erymentau
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 95 of 1200 | Lewisburg
# Processing Record 96 of 1200 | Central Coast
# Processing Record 97 of 1200 | Aledo
# Processing Record 98 of 1200 | Ağcabədi
# Processing Record 99 of 1200 | Port Talbot
# Processing Record 100 of 1200 | Piedmont
# Processing Record 101 of 1200 | Birsk
# Processing Record 102 of 1200 | Cerklje na Gorenjskem
# Processing Record 103 of 1200 | Jackson
# Processing Record 104 of 1200 | Tindouf
# Processing Record 105 of 1200 | Kontagora
# Processing Record 106 of 1200 | Dəvəçi
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 107 of 1200 | Cambridge
# Processing Record 108 of 1200 | Atascadero
# Processing Record 109 of 1200 | Hemet
# Processing Record 110 of 1200 | Vwawa
# Processing Record 111 of 1200 | Krasnokamsk
# Processing Record 112 of 1200 | Springs
# Processing Record 113 of 1200 | Gaalkacyo
# Processing Record 114 of 1200 | Chalatenango
# Processing Record 115 of 1200 | Mar del Plata
# Processing Record 116 of 1200 | Prebold
# Processing Record 117 of 1200 | Samara
# Processing Record 118 of 1200 | Dover
# Processing Record 119 of 1200 | Lititz
# Processing Record 120 of 1200 | Yorkton
# Processing Record 121 of 1200 | Sheikhu Pura
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 122 of 1200 | Joliette
# Processing Record 123 of 1200 | St.-Denis
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 124 of 1200 | Kanoya
# Processing Record 125 of 1200 | Monticello
# Processing Record 126 of 1200 | Għargħur
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 127 of 1200 | Visaginas
# Processing Record 128 of 1200 | Yozgat
# Processing Record 129 of 1200 | Locust Grove
# Processing Record 130 of 1200 | Tokat
# Processing Record 131 of 1200 | Vicente Guerrero
# Processing Record 132 of 1200 | Salem
# Processing Record 133 of 1200 | Eséka
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 134 of 1200 | San Antonio de los Cobres
# Processing Record 135 of 1200 | Rybinsk
# Processing Record 136 of 1200 | Same
# Processing Record 137 of 1200 | Nordvik
# Processing Record 138 of 1200 | Griffith
# Processing Record 139 of 1200 | Sechura
# Processing Record 140 of 1200 | Agadir
# Processing Record 141 of 1200 | Kotor
# Processing Record 142 of 1200 | Broadway
# Processing Record 143 of 1200 | Pohang
# Processing Record 144 of 1200 | Seven Hills
# Processing Record 145 of 1200 | Lynbrook
# Processing Record 146 of 1200 | Kashmar
# Processing Record 147 of 1200 | Narvik
# Processing Record 148 of 1200 | Pointe-Noire
# Processing Record 149 of 1200 | Bernalillo
# Processing Record 150 of 1200 | Schefferville
# Processing Record 151 of 1200 | Sokobanja
# Processing Record 152 of 1200 | Lao Chi
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 153 of 1200 | Sharon
# Processing Record 154 of 1200 | Oak Creek
# Processing Record 155 of 1200 | Pemagatshel
# Processing Record 156 of 1200 | Santiago de Cuba
# Processing Record 157 of 1200 | Bukama
# Processing Record 158 of 1200 | Munford
# Processing Record 159 of 1200 | Araguari
# Processing Record 160 of 1200 | Port Townsend
# Processing Record 161 of 1200 | Aglona
# Processing Record 162 of 1200 | Trofimovsk
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 163 of 1200 | Batu Pahat
# Processing Record 164 of 1200 | London
# Processing Record 165 of 1200 | New Milford
# Processing Record 166 of 1200 | Punta Arenas
# Processing Record 167 of 1200 | Rawson
# Processing Record 168 of 1200 | Oradea
# Processing Record 169 of 1200 | Guapi
# Processing Record 170 of 1200 | Chelsea
# Processing Record 171 of 1200 | Shashi
# Processing Record 172 of 1200 | South Beloit
# Processing Record 173 of 1200 | Tigoa
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 174 of 1200 | Uray
# Processing Record 175 of 1200 | Añatuya
# Processing Record 176 of 1200 | Hollywood
# Processing Record 177 of 1200 | Bellevue
# Processing Record 178 of 1200 | Lakemoor
# Processing Record 179 of 1200 | Luling
# Processing Record 180 of 1200 | Nizamabad
# Processing Record 181 of 1200 | Auburn
# Processing Record 182 of 1200 | Ikeja
# Processing Record 183 of 1200 | Dawmat al Jandal
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 184 of 1200 | Forest Grove
# Processing Record 185 of 1200 | Matsue
# Processing Record 186 of 1200 | Mandan
# Processing Record 187 of 1200 | Grevenmacher
# Processing Record 188 of 1200 | Encamp
# Processing Record 189 of 1200 | Melitopol
# Processing Record 190 of 1200 | Daloa
# Processing Record 191 of 1200 | Atmore
# Processing Record 192 of 1200 | Potenza
# Processing Record 193 of 1200 | Athens
# Processing Record 194 of 1200 | Pánuco
# Processing Record 195 of 1200 | Bol'sheretsk
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 196 of 1200 | Barretos
# Processing Record 197 of 1200 | Kole
# Processing Record 198 of 1200 | Chandler
# Processing Record 199 of 1200 | Port Orchard
# Processing Record 200 of 1200 | Tibati
# Processing Record 201 of 1200 | Carbondale
# Processing Record 202 of 1200 | Jefferson
# Processing Record 203 of 1200 | Androka
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 204 of 1200 | Razkrižje
# Processing Record 205 of 1200 | Marietta
# Processing Record 206 of 1200 | Gaspé
# Processing Record 207 of 1200 | Huber Heights
# Processing Record 208 of 1200 | Senta
# Processing Record 209 of 1200 | Ciudad Constitución
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 210 of 1200 | Zonguldak
# Processing Record 211 of 1200 | Port Pirie
# Processing Record 212 of 1200 | Molėtai
# Processing Record 213 of 1200 | Tete
# Processing Record 214 of 1200 | Willoughby
# Processing Record 215 of 1200 | Blaine
# Processing Record 216 of 1200 | Lorient
# Processing Record 217 of 1200 | Magway
# Processing Record 218 of 1200 | Machiques
# Processing Record 219 of 1200 | Middelburg
# Processing Record 220 of 1200 | Canfield
# Processing Record 221 of 1200 | Nerchinsk
# Processing Record 222 of 1200 | Sevierville
# Processing Record 223 of 1200 | Victor Harbor
# Processing Record 224 of 1200 | Capitola
# Processing Record 225 of 1200 | Macenta
# Processing Record 226 of 1200 | Tsiigehtchic
# Processing Record 227 of 1200 | Ar Ramadi
# Processing Record 228 of 1200 | Samarinda
# Processing Record 229 of 1200 | Smithville
# Processing Record 230 of 1200 | Salerno
# Processing Record 231 of 1200 | Heath
# Processing Record 232 of 1200 | Mills River
# Processing Record 233 of 1200 | Koidu
# Processing Record 234 of 1200 | Thu Dau Mot
# Processing Record 235 of 1200 | Warren
# Processing Record 236 of 1200 | Sobral
# Processing Record 237 of 1200 | Amapá
# Processing Record 238 of 1200 | Belmopan
# Processing Record 239 of 1200 | Esik
# Processing Record 240 of 1200 | Kirkuk
# Processing Record 241 of 1200 | Dunhua
# Processing Record 242 of 1200 | Kasungu
# Processing Record 243 of 1200 | Log pri Brezovici
# Processing Record 244 of 1200 | Guaranda
# Processing Record 245 of 1200 | Christiansburg
# Processing Record 246 of 1200 | Monmouth
# Processing Record 247 of 1200 | Middletown
# Processing Record 248 of 1200 | Svrljig
# Processing Record 249 of 1200 | Bayonne
# Processing Record 250 of 1200 | Rîşcani
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 251 of 1200 | Kontcha
# Processing Record 252 of 1200 | Irvine
# Processing Record 253 of 1200 | Mazatenango
# Processing Record 254 of 1200 | Oktyabrsk
# Processing Record 255 of 1200 | Puerto Acosta
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 256 of 1200 | New Hempstead
# Processing Record 257 of 1200 | Campobasso
# Processing Record 258 of 1200 | Lampang
# Processing Record 259 of 1200 | Emporia
# Processing Record 260 of 1200 | Hajjah
# Processing Record 261 of 1200 | Estância
# Processing Record 262 of 1200 | De Kastri
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 263 of 1200 | Tonganoxie
# Processing Record 264 of 1200 | Cam Ranh
# Processing Record 265 of 1200 | San Juan
# Processing Record 266 of 1200 | Williamsburg
# Processing Record 267 of 1200 | Yelm
# Processing Record 268 of 1200 | Vinnytsya
# Processing Record 269 of 1200 | Anamosa
# Processing Record 270 of 1200 | Bristol
# Processing Record 271 of 1200 | Aqsu
# Processing Record 272 of 1200 | LaFollette
# Processing Record 273 of 1200 | Uyar
# Processing Record 274 of 1200 | Nashville
# Processing Record 275 of 1200 | Curanilahue
# Processing Record 276 of 1200 | Baldone
# Processing Record 277 of 1200 | Bor
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 278 of 1200 | Quesada
# Processing Record 279 of 1200 | Holtville
# Processing Record 280 of 1200 | Norman
# Processing Record 281 of 1200 | Fairmont
# Processing Record 282 of 1200 | Domžale
# Processing Record 283 of 1200 | Sept-Îles
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 284 of 1200 | Despotovac
# Processing Record 285 of 1200 | Glarus
# Processing Record 286 of 1200 | Mahajanga
# Processing Record 287 of 1200 | Trenton
# Processing Record 288 of 1200 | Avon
# Processing Record 289 of 1200 | Windsor
# Processing Record 290 of 1200 | Gavarr
# Processing Record 291 of 1200 | Mae Sot
# Processing Record 292 of 1200 | Kabarnet
# Processing Record 293 of 1200 | Birštonas
# Processing Record 294 of 1200 | Wendell
# Processing Record 295 of 1200 | Flushing
# Processing Record 296 of 1200 | Fredericton
# Processing Record 297 of 1200 | Roselle
# Processing Record 298 of 1200 | Barentu
# Processing Record 299 of 1200 | Canoas
# Processing Record 300 of 1200 | Moss
# Processing Record 301 of 1200 | Isla Mujeres
# Processing Record 302 of 1200 | Ubaitaba
# Processing Record 303 of 1200 | El Tigre
# Processing Record 304 of 1200 | Fort McMurray
# Processing Record 305 of 1200 | Troy
# Processing Record 306 of 1200 | Puca Urco
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 307 of 1200 | Middleburg Heights
# Processing Record 308 of 1200 | Jinchang
# Processing Record 309 of 1200 | Vizianagaram
# Processing Record 310 of 1200 | Labasa
# Processing Record 311 of 1200 | Šalčininkai
# Processing Record 312 of 1200 | Gladstone
# Processing Record 313 of 1200 | Sharjah
# Processing Record 314 of 1200 | Zareh Sharan
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 315 of 1200 | Sorocaba
# Processing Record 316 of 1200 | Santa Bárbara
# Processing Record 317 of 1200 | Beebe
# Processing Record 318 of 1200 | María Elena
# Processing Record 319 of 1200 | Auburn
# Processing Record 320 of 1200 | Milledgeville
# Processing Record 321 of 1200 | Dezful
# Processing Record 322 of 1200 | Haugesund
# Processing Record 323 of 1200 | Susanville
# Processing Record 324 of 1200 | Everett
# Processing Record 325 of 1200 | Al Qunfudhah
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 326 of 1200 | Roosevelt
# Processing Record 327 of 1200 | Magas
# Processing Record 328 of 1200 | Kumo
# Processing Record 329 of 1200 | Rūjiena
# Processing Record 330 of 1200 | Grand Terrace
# Processing Record 331 of 1200 | Upernavik
# Processing Record 332 of 1200 | Whitehall
# Processing Record 333 of 1200 | Jalingo
# Processing Record 334 of 1200 | Governador Valadares
# Processing Record 335 of 1200 | Lawrenceville
# Processing Record 336 of 1200 | Auxerre
# Processing Record 337 of 1200 | Langfang
# Processing Record 338 of 1200 | Knoxville
# Processing Record 339 of 1200 | Maldonado
# Processing Record 340 of 1200 | Karpinsk
# Processing Record 341 of 1200 | Sibay
# Processing Record 342 of 1200 | Nazret
# Processing Record 343 of 1200 | Fort McPherson
# Processing Record 344 of 1200 | Waite Park
# Processing Record 345 of 1200 | Broken Hill
# Processing Record 346 of 1200 | San Fernando
# Processing Record 347 of 1200 | Villa Martin
# Processing Record 348 of 1200 | Byron Bay
# Processing Record 349 of 1200 | Athabasca
# Processing Record 350 of 1200 | Sodankylä
# Processing Record 351 of 1200 | Dunaújváros
# Processing Record 352 of 1200 | Ogre
# Processing Record 353 of 1200 | New Iberia
# Processing Record 354 of 1200 | Thomasville
# Processing Record 355 of 1200 | Meymaneh
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 356 of 1200 | Kronenwetter
# Processing Record 357 of 1200 | Shchekino
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 358 of 1200 | Willits
# Processing Record 359 of 1200 | Batavia
# Processing Record 360 of 1200 | Wellington
# Processing Record 361 of 1200 | Grenada
# Processing Record 362 of 1200 | Sochi
# Processing Record 363 of 1200 | Great Neck Plaza
# Processing Record 364 of 1200 | Shizuoka
# Processing Record 365 of 1200 | Budva
# Processing Record 366 of 1200 | Wadi Halfa
# Processing Record 367 of 1200 | Jerome
# Processing Record 368 of 1200 | North Salt Lake
# Processing Record 369 of 1200 | Manadhoo
# Processing Record 370 of 1200 | New Haven
# Processing Record 371 of 1200 | Usakos
# Processing Record 372 of 1200 | Buguruslan
# Processing Record 373 of 1200 | Victorica
# Processing Record 374 of 1200 | Ussuriysk
# Processing Record 375 of 1200 | København
# Processing Record 376 of 1200 | Pleasant Hills
# Processing Record 377 of 1200 | Ségou
# Processing Record 378 of 1200 | Vila de Sal Rei
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 379 of 1200 | Keene
# Processing Record 380 of 1200 | Krivogaštani
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 381 of 1200 | Cloquet
# Processing Record 382 of 1200 | Champaign
# Processing Record 383 of 1200 | Pingxiang
# Processing Record 384 of 1200 | Brockton
# Processing Record 385 of 1200 | Ağsu
# Processing Record 386 of 1200 | Glen Carbon
# Processing Record 387 of 1200 | Songkhla
# Processing Record 388 of 1200 | Vila da Ribeira Brava
# Processing Record 389 of 1200 | East Ham
# Processing Record 390 of 1200 | Lone Grove
# Processing Record 391 of 1200 | Sidi bel Abbes
# Processing Record 392 of 1200 | Moyeni
# Processing Record 393 of 1200 | Morant Bay
# Processing Record 394 of 1200 | Lake Dallas
# Processing Record 395 of 1200 | Monroe
# Processing Record 396 of 1200 | Greenock
# Processing Record 397 of 1200 | Fort Lee
# Processing Record 398 of 1200 | Bellevue
# Processing Record 399 of 1200 | West University Place
# Processing Record 400 of 1200 | Mardan
# Processing Record 401 of 1200 | Narayanganj
# Processing Record 402 of 1200 | Harstad
# Processing Record 403 of 1200 | Lake Bluff
# Processing Record 404 of 1200 | Margate City
# Processing Record 405 of 1200 | Pleasant Grove
# Processing Record 406 of 1200 | Buyant-Uhaa
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 407 of 1200 | Araouane
# Processing Record 408 of 1200 | Tecumseh
# Processing Record 409 of 1200 | Nitra
# Processing Record 410 of 1200 | Chinandega
# Processing Record 411 of 1200 | Constantine
# Processing Record 412 of 1200 | Borger
# Processing Record 413 of 1200 | Nevelsk
# Processing Record 414 of 1200 | Richfield
# Processing Record 415 of 1200 | Talara
# Processing Record 416 of 1200 | Naryan Mar
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 417 of 1200 | Yaounde
# Processing Record 418 of 1200 | Tazovsky
# Processing Record 419 of 1200 | Zaria
# Processing Record 420 of 1200 | Bolobo
# Processing Record 421 of 1200 | Princes Town
# Processing Record 422 of 1200 | Felipe Carrillo Puerto
# Processing Record 423 of 1200 | Lamphun
# Processing Record 424 of 1200 | Perry
# Processing Record 425 of 1200 | Lincolnshire
# Processing Record 426 of 1200 | Mparo
# Processing Record 427 of 1200 | Traverse City
# Processing Record 428 of 1200 | Lebu
# Processing Record 429 of 1200 | Gaya
# Processing Record 430 of 1200 | Compostela
# Processing Record 431 of 1200 | Votkinsk
# Processing Record 432 of 1200 | Motupe
# Processing Record 433 of 1200 | Sorata
# Processing Record 434 of 1200 | Walla Walla
# Processing Record 435 of 1200 | Brookfield
# Processing Record 436 of 1200 | Gadsden
# Processing Record 437 of 1200 | Green
# Processing Record 438 of 1200 | Kuantan
# Processing Record 439 of 1200 | Lapa
# Processing Record 440 of 1200 | Santiago Tuxtla
# Processing Record 441 of 1200 | Picton
# Processing Record 442 of 1200 | Mount Vernon
# Processing Record 443 of 1200 | Skikda
# Processing Record 444 of 1200 | Tavares
# Processing Record 445 of 1200 | Pedernales
# Processing Record 446 of 1200 | Hiroshima
# Processing Record 447 of 1200 | Mikkeli
# Processing Record 448 of 1200 | Calatrava
# Processing Record 449 of 1200 | Konya
# Processing Record 450 of 1200 | Chino Hills
# Processing Record 451 of 1200 | Montclair
# Processing Record 452 of 1200 | Novocherkassk
# Processing Record 453 of 1200 | Aleysk
# Processing Record 454 of 1200 | Paisley
# Processing Record 455 of 1200 | Asaba
# Processing Record 456 of 1200 | Lithgow
# Processing Record 457 of 1200 | Grafton
# Processing Record 458 of 1200 | Mullingar
# Processing Record 459 of 1200 | Airmont
# Processing Record 460 of 1200 | Clarksdale
# Processing Record 461 of 1200 | Alice Springs
# Processing Record 462 of 1200 | Santa Paula
# Processing Record 463 of 1200 | Rustavi
# Processing Record 464 of 1200 | Zicheng
# Processing Record 465 of 1200 | Sharya
# Processing Record 466 of 1200 | Nelson
# Processing Record 467 of 1200 | Twentynine Palms
# Processing Record 468 of 1200 | Bexleyheath
# Processing Record 469 of 1200 | Jiujiang
# Processing Record 470 of 1200 | 25 de Mayo
# Processing Record 471 of 1200 | Gilberts
# Processing Record 472 of 1200 | Xuanzhou
# Processing Record 473 of 1200 | Bainbridge
# Processing Record 474 of 1200 | Berovo
# Processing Record 475 of 1200 | Urbana
# Processing Record 476 of 1200 | Opovo
# Processing Record 477 of 1200 | Phayao
# Processing Record 478 of 1200 | Naukšēni
# Processing Record 479 of 1200 | Millington
# Processing Record 480 of 1200 | Menongue
# Processing Record 481 of 1200 | Viļāni
# Processing Record 482 of 1200 | Cambridge
# Processing Record 483 of 1200 | Imperial Beach
# Processing Record 484 of 1200 | Kwinana
# Processing Record 485 of 1200 | Bacabal
# Processing Record 486 of 1200 | Countryside
# Processing Record 487 of 1200 | Charters Towers
# Processing Record 488 of 1200 | Shkodër
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 489 of 1200 | Roboré
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 490 of 1200 | Gaylord
# Processing Record 491 of 1200 | Megion
# Processing Record 492 of 1200 | Stone Mountain
# Processing Record 493 of 1200 | Duarte
# Processing Record 494 of 1200 | South Sioux City
# Processing Record 495 of 1200 | Ceres
# Processing Record 496 of 1200 | Maués
# Processing Record 497 of 1200 | Borovnica
# Processing Record 498 of 1200 | Phichit
# Processing Record 499 of 1200 | Gaoua
# Processing Record 500 of 1200 | Ikšķile
# Processing Record 501 of 1200 | Forecariah
# Processing Record 502 of 1200 | Amolatar
# Processing Record 503 of 1200 | Folsom
# Processing Record 504 of 1200 | Codó
# Processing Record 505 of 1200 | Qinggang
# Processing Record 506 of 1200 | Juan José Castelli
# Processing Record 507 of 1200 | Portoviejo
# Processing Record 508 of 1200 | Zgornja Kungota
# Processing Record 509 of 1200 | Bhairawa
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 510 of 1200 | Río Gallegos
# Processing Record 511 of 1200 | Prijedor
# Processing Record 512 of 1200 | Ljubovija
# Processing Record 513 of 1200 | Kislovodsk
# Processing Record 514 of 1200 | Hood River
# Processing Record 515 of 1200 | Galax
# Processing Record 516 of 1200 | Mossendjo
# Processing Record 517 of 1200 | Skuodas
# Processing Record 518 of 1200 | Lakatoro
# Processing Record 519 of 1200 | Blaine
# Processing Record 520 of 1200 | Pati
# Processing Record 521 of 1200 | Auki
# Processing Record 522 of 1200 | Tauragė
# Processing Record 523 of 1200 | Sand Springs
# Processing Record 524 of 1200 | Hanoi
# Processing Record 525 of 1200 | Newport News
# Processing Record 526 of 1200 | Capitão Poço
# Processing Record 527 of 1200 | City of Milford (balance)
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 528 of 1200 | Nuevo Rocafuerte
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 529 of 1200 | Qeqertasuaq
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 530 of 1200 | Delano
# Processing Record 531 of 1200 | Pisa
# Processing Record 532 of 1200 | Avaré
# Processing Record 533 of 1200 | Zlín
# Processing Record 534 of 1200 | Akmenė
# Processing Record 535 of 1200 | As Sib
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 536 of 1200 | Ashland
# Processing Record 537 of 1200 | Orange Beach
# Processing Record 538 of 1200 | Đồng Hới
# Processing Record 539 of 1200 | Fircrest
# Processing Record 540 of 1200 | Rietavas
# Processing Record 541 of 1200 | Mavinga
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 542 of 1200 | Mumbwa
# Processing Record 543 of 1200 | Dana Point
# Processing Record 544 of 1200 | Bristol
# Processing Record 545 of 1200 | Bhiwani
# Processing Record 546 of 1200 | Ciudad Madero
# Processing Record 547 of 1200 | Grobiņa
# Processing Record 548 of 1200 | Hoshiarpur
# Processing Record 549 of 1200 | Hangu
# Processing Record 550 of 1200 | Homyel
# Processing Record 551 of 1200 | Kruševac
# Processing Record 552 of 1200 | Pleasant Hill
# Processing Record 553 of 1200 | Düsseldorf
# Processing Record 554 of 1200 | Mission
# Processing Record 555 of 1200 | Monticello
# Processing Record 556 of 1200 | Puerto López
# Processing Record 557 of 1200 | Downpatrick
# Processing Record 558 of 1200 | Concórdia
# Processing Record 559 of 1200 | Plainfield
# Processing Record 560 of 1200 | Mitoma
# Processing Record 561 of 1200 | Church Hill
# Processing Record 562 of 1200 | Moranbah
# Processing Record 563 of 1200 | Xichang
# Processing Record 564 of 1200 | Villahermosa
# Processing Record 565 of 1200 | Mandya
# Processing Record 566 of 1200 | Manizales
# Processing Record 567 of 1200 | Chosan
# Processing Record 568 of 1200 | Perris
# Processing Record 569 of 1200 | Dar'a
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 570 of 1200 | Cathedral City
# Processing Record 571 of 1200 | Live Oak
# Processing Record 572 of 1200 | Leesville
# Processing Record 573 of 1200 | Dayton
# Processing Record 574 of 1200 | Ulaangom
# Processing Record 575 of 1200 | Hosaina
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 576 of 1200 | Eydhafushi
# Processing Record 577 of 1200 | Santiago de Compostela
# Processing Record 578 of 1200 | Healdsburg
# Processing Record 579 of 1200 | Carrick on Shannon
# Processing Record 580 of 1200 | El Calafate
# Processing Record 581 of 1200 | Maiduguri
# Processing Record 582 of 1200 | Ygatimí
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 583 of 1200 | Ostrava
# Processing Record 584 of 1200 | Winnemucca
# Processing Record 585 of 1200 | Alofi
# Processing Record 586 of 1200 | Teyateyaneng
# Processing Record 587 of 1200 | Mokhotlong
# Processing Record 588 of 1200 | Lemont
# Processing Record 589 of 1200 | Lake Wales
# Processing Record 590 of 1200 | Xiangtai
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 591 of 1200 | Gorakhpur
# Processing Record 592 of 1200 | Zabol
# Processing Record 593 of 1200 | Tucuruí
# Processing Record 594 of 1200 | Itapetininga
# Processing Record 595 of 1200 | Chiang Rai
# Processing Record 596 of 1200 | Da Nang
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 597 of 1200 | Suffolk
# Processing Record 598 of 1200 | Jeju
# Processing Record 599 of 1200 | Asbury
# Processing Record 600 of 1200 | Changyon
# Processing Record 601 of 1200 | Canillo
# Processing Record 602 of 1200 | Galway
# Processing Record 603 of 1200 | Gonbad-e Kavus
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 604 of 1200 | Brovary
# Processing Record 605 of 1200 | Hakha
# Processing Record 606 of 1200 | Cao Bằng
# Processing Record 607 of 1200 | Canavieiras
# Processing Record 608 of 1200 | Waverly
# Processing Record 609 of 1200 | Ulm
# Processing Record 610 of 1200 | West Memphis
# Processing Record 611 of 1200 | Athens
# Processing Record 612 of 1200 | Pelotas
# Processing Record 613 of 1200 | Elmhurst
# Processing Record 614 of 1200 | Pewaukee
# Processing Record 615 of 1200 | Hims
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 616 of 1200 | Caxias do Sul
# Processing Record 617 of 1200 | Bairnsdale
# Processing Record 618 of 1200 | Vandalia
# Processing Record 619 of 1200 | Zapala
# Processing Record 620 of 1200 | Taylor
# Processing Record 621 of 1200 | Hyeson
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 622 of 1200 | Agartala
# Processing Record 623 of 1200 | Celina
# Processing Record 624 of 1200 | Bayghanin
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 625 of 1200 | Nyahanga
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 626 of 1200 | Zalaegerszeg
# Processing Record 627 of 1200 | Zaraza
# Processing Record 628 of 1200 | Toowoomba
# Processing Record 629 of 1200 | Qala
# Processing Record 630 of 1200 | Garoowe
# Processing Record 631 of 1200 | Phan Thiet
# Processing Record 632 of 1200 | Phrae
# Processing Record 633 of 1200 | Kyakhta
# Processing Record 634 of 1200 | Ukhta
# Processing Record 635 of 1200 | Stanwood
# Processing Record 636 of 1200 | Amuru
# Processing Record 637 of 1200 | Plast
# Processing Record 638 of 1200 | Xinxiang
# Processing Record 639 of 1200 | Stickney
# Processing Record 640 of 1200 | La Sarre
# Processing Record 641 of 1200 | Tomball
# Processing Record 642 of 1200 | Niğde
# Processing Record 643 of 1200 | Hinche
# Processing Record 644 of 1200 | Tsumeb
# Processing Record 645 of 1200 | Hamilton
# Processing Record 646 of 1200 | Bonao
# Processing Record 647 of 1200 | Wagga Wagga
# Processing Record 648 of 1200 | Cao Lãnh
# Processing Record 649 of 1200 | Central
# Processing Record 650 of 1200 | Pooler
# Processing Record 651 of 1200 | Beringovskiy
# Processing Record 652 of 1200 | Benha
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# That key doesn't exist
# Processing Record 653 of 1200 | Almetyevsk
# Processing Record 654 of 1200 | Bossier City
# Processing Record 655 of 1200 | Lake Villa
# Processing Record 656 of 1200 | Mednogorsk
# Processing Record 657 of 1200 | Eagan
# Processing Record 658 of 1200 | Simpsonville
# Processing Record 659 of 1200 | Maplewood
# Processing Record 660 of 1200 | Brooksville
# Processing Record 661 of 1200 | Big Spring
# Processing Record 662 of 1200 | Viseu
# Processing Record 663 of 1200 | Camargo
# Processing Record 664 of 1200 | Waterford
# Processing Record 665 of 1200 | Khorugh
# Processing Record 666 of 1200 | Roselle Park
# Processing Record 667 of 1200 | Tamanrasset
# Processing Record 668 of 1200 | Gillam
# Processing Record 669 of 1200 | Tougan
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-23-0e0483627431> in <module>
#      24     print(f"Processing Record {record_cnt} of {list_len} | {city}")
#      25     query_url = f"{url}appid={api_key}&units={units}&q={city}"
# ---> 26     response = requests.get(query_url).json()
#      27
#      28     try:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a dictionary from the raw data
raw_weather_data = {"City": name,
                   "Cloudiness": clouds,
                   "Date": date,
                   "Humidity": humidity,
                   "Max Temp": temp_max,
                   "Wind Speed": wind_speed}

# %%
#create a datafram from the dictionary
weather_data = pd.DataFrame(raw_weather_data)

# %%
#merge the dataframe with the lats and longs with the dataframe with the weather information
city_weather_data = pd.merge(weather_data,random_cities, on="city")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Max Temp"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Max Temperature ({now.month}/{now.day}/{now.year})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig('LatvsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Humidity"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Humidity ({now.month}/{now.day}/{now.year})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsHumid.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Cloudiness"]
plt.xlim(-60,80)
plt.ylim(0,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Cloudiness ({now.month}/{now.day}/{now.year})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Wind Speed"]
plt.xlim(-60,80)
plt.ylim(0,30)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Wind Speed ({now.month}/{now.day}/{now.year})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.savefig('LatvsWind.png')
plt.show()
