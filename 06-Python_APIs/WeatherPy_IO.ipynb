# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
#
# There were few observable trends that I noticed.
#
# First it seems like most of the weather output were varied but more in the Northern hemipshere. This is as a result of the weather changes and the time of the year.
#
# The maximum temperatures are concentrated in the northern hemisphere and this is because there is more population in the northern hemisphere and thus more cities.
#
# Humidity is concentrated in the temperate to tropical regions and more so in the northern hemisphere.
#
# Bonus: There is a weird pattern in the cloudiness plot and I am not sure what it means.

# %% [markdown]
# ## Generate Cities List

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime


now = datetime.datetime.now()

# %%
# Import API key
from api_keys import api_key

# %%
# Output File (CSV)
citi_list = pd.read_csv("worldcities.csv")

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Choose a random sample of 100 cities
random_cities = citi_list.sample(n=700)

# %%
#view dataframe of random cities
random_cities.head()
# Out:
#           city city_ascii      lat      lng        country iso2 iso3  \
# 7692     Rasht      Rasht  37.3000  49.6300           Iran   IR  IRN
# 1785   Karachi    Karachi  24.8700  66.9900       Pakistan   PK  PAK
# 5149  Gaborone   Gaborone -24.6463  25.9119       Botswana   BW  BWA
# 8599   Dunedin    Dunedin  28.0328 -82.7865  United States   US  USA
# 6706     Reims      Reims  49.2504   4.0300         France   FR  FRA
#
#      admin_name  capital  population          id
# 7692      Gīlān    admin    594590.0  1364630382
# 1785      Sindh    admin  12130000.0  1586129469
# 5149   Gaborone  primary    208411.0  1072756768
# 8599    Florida      NaN     36381.0  1840014144
# 6706  Grand Est      NaN    196565.0  1250608730

# %%
#create a series of cities
citi_search_list = random_cities.city

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create a series of cities
city_search_list = random_cities.city

# %%
#create several lists to hold raw data
name = []
clouds = []
date = []
humidity = []
temp_max = []
wind_speed = []

#log the length of the series
list_len = len(city_search_list)

#specify the base url
url = "http://api.openweathermap.org/data/2.5/weather?"

#set the measurement system
units = "imperial"

#initialize a variable for the record count
record_cnt = 1

#create a loop to get the information for all the cities and add them to the lists
#also add error handling
for city in city_search_list:
    print(f"Processing Record {record_cnt} of {list_len} | {city}")
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    response = requests.get(query_url).json()
    
    try:
        name.append(response["name"].lower())
    except KeyError:
        print("key is missing")
        
    try:
        clouds.append(response["clouds"]["all"])
    except KeyError:
        print("key is missing")
            
    try:
        date.append(response["dt"])
    except KeyError:
        print("key is missing")
                
    try:
        humidity.append(response["main"]["humidity"])
    except KeyError:
        print("key is missing")
                    
    try:
        temp_max.append(response["main"]["temp_max"])
    except KeyError:
        print("key is missing")
                        
    try:
        wind_speed.append(response["wind"]["speed"])
    except KeyError:
        print("key is missing")
        
    #iterate the record count on each loop
    record_cnt = record_cnt + 1
# Out:
# Processing Record 1 of 700 | Rasht
# Processing Record 2 of 700 | Karachi
# Processing Record 3 of 700 | Gaborone
# Processing Record 4 of 700 | Dunedin
# Processing Record 5 of 700 | Reims
# Processing Record 6 of 700 | Vijayawada
# Processing Record 7 of 700 | Brindisi
# Processing Record 8 of 700 | Radoviš
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 9 of 700 | Corbin
# Processing Record 10 of 700 | Puca Urco
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 11 of 700 | Midlothian
# Processing Record 12 of 700 | Sveti Nikole
# Processing Record 13 of 700 | Yalutorovsk
# Processing Record 14 of 700 | Buffalo Grove
# Processing Record 15 of 700 | Telukbutun
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 16 of 700 | Milton
# Processing Record 17 of 700 | Gorno Altaysk
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 18 of 700 | Alenquer
# Processing Record 19 of 700 | Fredericksburg
# Processing Record 20 of 700 | Cibitoke
# Processing Record 21 of 700 | Omak
# Processing Record 22 of 700 | Santa Ana
# Processing Record 23 of 700 | Dimitrovgrad
# Processing Record 24 of 700 | Wellington
# Processing Record 25 of 700 | Usakos
# Processing Record 26 of 700 | Porto Santana
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 27 of 700 | Bremerhaven
# Processing Record 28 of 700 | King City
# Processing Record 29 of 700 | Tunuyán
# Processing Record 30 of 700 | Sarnia
# Processing Record 31 of 700 | Warwick
# Processing Record 32 of 700 | Itacoatiara
# Processing Record 33 of 700 | Lynwood
# Processing Record 34 of 700 | Forrest City
# Processing Record 35 of 700 | Bairnsdale
# Processing Record 36 of 700 | Mtwara
# Processing Record 37 of 700 | Hopkins
# Processing Record 38 of 700 | Royal Palm Beach
# Processing Record 39 of 700 | Wiltz
# Processing Record 40 of 700 | Elk Grove
# Processing Record 41 of 700 | Roseville
# Processing Record 42 of 700 | Warwick
# Processing Record 43 of 700 | Statesville
# Processing Record 44 of 700 | Fair Haven
# Processing Record 45 of 700 | Hanahan
# Processing Record 46 of 700 | Truro
# Processing Record 47 of 700 | Somerdale
# Processing Record 48 of 700 | Kiselevsk
# Processing Record 49 of 700 | Toppenish
# Processing Record 50 of 700 | Andoas
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 51 of 700 | North Chicago
# Processing Record 52 of 700 | Halmstad
# Processing Record 53 of 700 | La Mirada
# Processing Record 54 of 700 | Wyomissing
# Processing Record 55 of 700 | Millbrook
# Processing Record 56 of 700 | Holdrege
# Processing Record 57 of 700 | Bristol
# Processing Record 58 of 700 | Youngtown
# Processing Record 59 of 700 | Rečica ob Savinji
# Processing Record 60 of 700 | Cape Coast
# Processing Record 61 of 700 | Alert
# Processing Record 62 of 700 | Tulcán
# Processing Record 63 of 700 | Juan Aldama
# Processing Record 64 of 700 | Kota
# Processing Record 65 of 700 | Pinole
# Processing Record 66 of 700 | Kenora
# Processing Record 67 of 700 | Fraser
# Processing Record 68 of 700 | Uzhur
# Processing Record 69 of 700 | Eindhoven
# Processing Record 70 of 700 | Wilsonville
# Processing Record 71 of 700 | Gwadar
# Processing Record 72 of 700 | Bogoroditsk
# Processing Record 73 of 700 | Hurdiyo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 74 of 700 | Nogales
# Processing Record 75 of 700 | Gladstone
# Processing Record 76 of 700 | Farmington Hills
# Processing Record 77 of 700 | Murray
# Processing Record 78 of 700 | Wanaque
# Processing Record 79 of 700 | Pendleton
# Processing Record 80 of 700 | Abaí
# Processing Record 81 of 700 | Thulusdhoo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 82 of 700 | San Quintín
# Processing Record 83 of 700 | Barinas
# Processing Record 84 of 700 | Porbandar
# Processing Record 85 of 700 | Acaraú
# Processing Record 86 of 700 | Terrell
# Processing Record 87 of 700 | Marovoay
# Processing Record 88 of 700 | Klyuchi
# Processing Record 89 of 700 | North Bend
# Processing Record 90 of 700 | Black River
# Processing Record 91 of 700 | Des Peres
# Processing Record 92 of 700 | Anshan
# Processing Record 93 of 700 | Port Macquarie
# Processing Record 94 of 700 | Saveh
# Processing Record 95 of 700 | Newcastle
# Processing Record 96 of 700 | Lake City
# Processing Record 97 of 700 | Lubbock
# Processing Record 98 of 700 | Cape Girardeau
# Processing Record 99 of 700 | Palm Beach
# Processing Record 100 of 700 | Mwanza
# Processing Record 101 of 700 | Superior
# Processing Record 102 of 700 | Naval
# Processing Record 103 of 700 | Chivilcoy
# Processing Record 104 of 700 | Lishui
# Processing Record 105 of 700 | Bairin Zuoqi
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 106 of 700 | Az Zawiyah
# Processing Record 107 of 700 | Poplar
# Processing Record 108 of 700 | Ipú
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 109 of 700 | Dolneni
# Processing Record 110 of 700 | Karasuk
# Processing Record 111 of 700 | Manassas
# Processing Record 112 of 700 | Northampton
# Processing Record 113 of 700 | Brăila
# Processing Record 114 of 700 | Zaporizhzhya
# Processing Record 115 of 700 | McMinns Lagoon
# Processing Record 116 of 700 | Hermiston
# Processing Record 117 of 700 | Minsk
# Processing Record 118 of 700 | Springfield
# Processing Record 119 of 700 | Sevnica
# Processing Record 120 of 700 | Majene
# Processing Record 121 of 700 | Echuca
# Processing Record 122 of 700 | Plattsburgh
# Processing Record 123 of 700 | Corner Brook
# Processing Record 124 of 700 | Helena
# Processing Record 125 of 700 | Lobamba
# Processing Record 126 of 700 | Limbaži
# Processing Record 127 of 700 | Buchans
# Processing Record 128 of 700 | Pazin
# Processing Record 129 of 700 | Kipili
# Processing Record 130 of 700 | Derzhavinsk
# Processing Record 131 of 700 | Voronezh
# Processing Record 132 of 700 | Forest Lake
# Processing Record 133 of 700 | Mostaganem
# Processing Record 134 of 700 | Llallagua
# Processing Record 135 of 700 | Maintirano
# Processing Record 136 of 700 | Sabanalarga
# Processing Record 137 of 700 | Granada‎
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 138 of 700 | Pala
# Processing Record 139 of 700 | Slovenske Konjice
# Processing Record 140 of 700 | Linton
# Processing Record 141 of 700 | Prineville
# Processing Record 142 of 700 | Bridgeport
# Processing Record 143 of 700 | Shakhty
# Processing Record 144 of 700 | San Felipe
# Processing Record 145 of 700 | Orillia
# Processing Record 146 of 700 | Shadrinsk
# Processing Record 147 of 700 | Monroe
# Processing Record 148 of 700 | Conshohocken
# Processing Record 149 of 700 | Chumbicha
# Processing Record 150 of 700 | Ghanzi
# Processing Record 151 of 700 | Broussard
# Processing Record 152 of 700 | Ar Rayyān
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 153 of 700 | West Lafayette
# Processing Record 154 of 700 | Santiago Tuxtla
# Processing Record 155 of 700 | Dalaba
# Processing Record 156 of 700 | Sparks
# Processing Record 157 of 700 | Bonita Springs
# Processing Record 158 of 700 | Ashland
# Processing Record 159 of 700 | Ajmer
# Processing Record 160 of 700 | Chester
# Processing Record 161 of 700 | Put Lenina
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 162 of 700 | Davao
# Processing Record 163 of 700 | Penola
# Processing Record 164 of 700 | Karasburg
# Processing Record 165 of 700 | Lambeth
# Processing Record 166 of 700 | Ar Rutbah
# Processing Record 167 of 700 | Newtownabbey
# Processing Record 168 of 700 | Margate
# Processing Record 169 of 700 | Clermont-Ferrand
# Processing Record 170 of 700 | Logansport
# Processing Record 171 of 700 | Yantai
# Processing Record 172 of 700 | Mentor
# Processing Record 173 of 700 | Petrópolis
# Processing Record 174 of 700 | Ridley Park
# Processing Record 175 of 700 | Matam
# Processing Record 176 of 700 | San Lorenzo
# Processing Record 177 of 700 | Botucatu
# Processing Record 178 of 700 | New Martinsville
# Processing Record 179 of 700 | Albany
# Processing Record 180 of 700 | Osečina
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 181 of 700 | Polokwane
# Processing Record 182 of 700 | Mersin
# Processing Record 183 of 700 | Bắc Ninh
# Processing Record 184 of 700 | Apatity
# Processing Record 185 of 700 | Indio
# Processing Record 186 of 700 | Los Gatos
# Processing Record 187 of 700 | Miass
# Processing Record 188 of 700 | Staro Nagoričane
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 189 of 700 | Zelenokumsk
# Processing Record 190 of 700 | Gitarama
# Processing Record 191 of 700 | Hengshui
# Processing Record 192 of 700 | Aral
# Processing Record 193 of 700 | Paw Paw
# Processing Record 194 of 700 | Owando
# Processing Record 195 of 700 | Kakinada
# Processing Record 196 of 700 | Athens
# Processing Record 197 of 700 | Leeds
# Processing Record 198 of 700 | Darwin
# Processing Record 199 of 700 | Ptuj
# Processing Record 200 of 700 | Ulaan-Uul
# Processing Record 201 of 700 | Matsumoto
# Processing Record 202 of 700 | Mejillones
# Processing Record 203 of 700 | Kassala
# Processing Record 204 of 700 | Barcelos
# Processing Record 205 of 700 | Novato
# Processing Record 206 of 700 | Goodyear
# Processing Record 207 of 700 | Kəlbəcər
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 208 of 700 | Somerville
# Processing Record 209 of 700 | Fort Mill
# Processing Record 210 of 700 | Lahad Datu
# Processing Record 211 of 700 | Chicksands
# Processing Record 212 of 700 | Glenwood Springs
# Processing Record 213 of 700 | Hawthorne
# Processing Record 214 of 700 | Alexandria
# Processing Record 215 of 700 | Poggio di Chiesanuova
# Processing Record 216 of 700 | Chalkida
# Processing Record 217 of 700 | Alibunar
# Processing Record 218 of 700 | Nadym
# Processing Record 219 of 700 | Mwingi
# Processing Record 220 of 700 | Palos Hills
# Processing Record 221 of 700 | Bonn
# Processing Record 222 of 700 | Aguascalientes
# Processing Record 223 of 700 | Fairport
# Processing Record 224 of 700 | Ayr
# Processing Record 225 of 700 | Conneaut
# Processing Record 226 of 700 | Longview
# Processing Record 227 of 700 | Maidenhead
# Processing Record 228 of 700 | Marsabit
# Processing Record 229 of 700 | Salamanca
# Processing Record 230 of 700 | Shelburne
# Processing Record 231 of 700 | Pativilca
# Processing Record 232 of 700 | Imperatriz
# Processing Record 233 of 700 | Fostoria
# Processing Record 234 of 700 | Lwengo
# Processing Record 235 of 700 | Butler
# Processing Record 236 of 700 | Għasri
# Processing Record 237 of 700 | Baydhabo
# Processing Record 238 of 700 | Quaraí
# Processing Record 239 of 700 | Hackensack
# Processing Record 240 of 700 | Dalian
# Processing Record 241 of 700 | Palangkaraya
# Processing Record 242 of 700 | Linfen
# Processing Record 243 of 700 | Ilford
# Processing Record 244 of 700 | Chester
# Processing Record 245 of 700 | Aurora
# Processing Record 246 of 700 | Kollam
# Processing Record 247 of 700 | Pagėgiai
# Processing Record 248 of 700 | Kalachinsk
# Processing Record 249 of 700 | Annecy
# Processing Record 250 of 700 | San Justo
# Processing Record 251 of 700 | Great Bend
# Processing Record 252 of 700 | Peterborough
# Processing Record 253 of 700 | Kiel
# Processing Record 254 of 700 | Farim
# Processing Record 255 of 700 | Ugolnye Kopi
# Processing Record 256 of 700 | Orhei
# Processing Record 257 of 700 | Donetsk
# Processing Record 258 of 700 | Sremska Mitrovica
# Processing Record 259 of 700 | Yambio
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 260 of 700 | Sobral
# Processing Record 261 of 700 | Maastricht
# Processing Record 262 of 700 | Bougouni
# Processing Record 263 of 700 | Ad Damazīn
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 264 of 700 | Malayer
# Processing Record 265 of 700 | Sikar
# Processing Record 266 of 700 | Khanty Mansiysk
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 267 of 700 | Şəmkir
# Processing Record 268 of 700 | Vorontsovo
# Processing Record 269 of 700 | Millersville
# Processing Record 270 of 700 | Río Bueno
# Processing Record 271 of 700 | Puerto Deseado
# Processing Record 272 of 700 | Assis
# Processing Record 273 of 700 | Churchill
# Processing Record 274 of 700 | Qui Nhon
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 275 of 700 | Lovington
# Processing Record 276 of 700 | Andamooka
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 277 of 700 | Florianópolis
# Processing Record 278 of 700 | Anniston
# Processing Record 279 of 700 | Eagle Mountain
# Processing Record 280 of 700 | Fairlawn
# Processing Record 281 of 700 | Ōita
# Processing Record 282 of 700 | Newark
# Processing Record 283 of 700 | Mons
# Processing Record 284 of 700 | Golfito
# Processing Record 285 of 700 | Alexandria
# Processing Record 286 of 700 | Dehibat
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 287 of 700 | Cotati
# Processing Record 288 of 700 | Avon
# Processing Record 289 of 700 | Acatlan
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 290 of 700 | South Daytona
# Processing Record 291 of 700 | Ondorhaan
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 292 of 700 | Selfoss
# Processing Record 293 of 700 | Three Springs
# Processing Record 294 of 700 | Stari Trg pri Ložu
# Processing Record 295 of 700 | Spassk Dalniy
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 296 of 700 | Little Current
# Processing Record 297 of 700 | Strongsville
# Processing Record 298 of 700 | Koulamoutou
# Processing Record 299 of 700 | Weyburn
# Processing Record 300 of 700 | Kuopio
# Processing Record 301 of 700 | Melrose Park
# Processing Record 302 of 700 | Herkimer
# Processing Record 303 of 700 | Hola
# Processing Record 304 of 700 | Duquesne
# Processing Record 305 of 700 | Nova Varoš
# Processing Record 306 of 700 | Monroe
# Processing Record 307 of 700 | Khorugh
# Processing Record 308 of 700 | Los Lagos
# Processing Record 309 of 700 | Doljevac
# Processing Record 310 of 700 | Panshi
# Processing Record 311 of 700 | Galt
# Processing Record 312 of 700 | Pembroke
# Processing Record 313 of 700 | El Cerrito
# Processing Record 314 of 700 | Bollnäs
# Processing Record 315 of 700 | Taiyuan
# Processing Record 316 of 700 | Oelwein
# Processing Record 317 of 700 | Beipiao
# Processing Record 318 of 700 | Russells Point
# Processing Record 319 of 700 | Prince George
# Processing Record 320 of 700 | Fairview Park
# Processing Record 321 of 700 | Chickasaw
# Processing Record 322 of 700 | Macenta
# Processing Record 323 of 700 | Fayetteville
# Processing Record 324 of 700 | Smederevska Palanka
# Processing Record 325 of 700 | Al Qunfudhah
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 326 of 700 | Fort Shevchenko
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 327 of 700 | Rockdale
# Processing Record 328 of 700 | Tucumán
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 329 of 700 | Qalat
# Processing Record 330 of 700 | San Antonio de los Baños
# Processing Record 331 of 700 | Sebring
# Processing Record 332 of 700 | Garbahaarey
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 333 of 700 | Yakima
# Processing Record 334 of 700 | Long Beach
# Processing Record 335 of 700 | Milwaukie
# Processing Record 336 of 700 | Denpasar
# Processing Record 337 of 700 | Voinjama
# Processing Record 338 of 700 | Tillabéri
# Processing Record 339 of 700 | Kapuskasing
# Processing Record 340 of 700 | Havre
# Processing Record 341 of 700 | Sarnen
# Processing Record 342 of 700 | Shuozhou
# Processing Record 343 of 700 | West Point
# Processing Record 344 of 700 | Whiteville
# Processing Record 345 of 700 | Highwood
# Processing Record 346 of 700 | San Antonio
# Processing Record 347 of 700 | The Hague
# Processing Record 348 of 700 | Krško
# Processing Record 349 of 700 | Kalbarri
# Processing Record 350 of 700 | Madang
# Processing Record 351 of 700 | Milton
# Processing Record 352 of 700 | Vasilevo
# Processing Record 353 of 700 | Ragana
# Processing Record 354 of 700 | Flint
# Processing Record 355 of 700 | Stavanger
# Processing Record 356 of 700 | Digby
# Processing Record 357 of 700 | Izmayil
# Processing Record 358 of 700 | Guanare
# Processing Record 359 of 700 | Muskego
# Processing Record 360 of 700 | Auce
# Processing Record 361 of 700 | Port Hardy
# Processing Record 362 of 700 | Worth
# Processing Record 363 of 700 | Mount Airy
# Processing Record 364 of 700 | Jima
# Processing Record 365 of 700 | Bawku
# Processing Record 366 of 700 | Ladue
# Processing Record 367 of 700 | Urbana
# Processing Record 368 of 700 | Katy
# Processing Record 369 of 700 | Pune
# Processing Record 370 of 700 | Bolu
# Processing Record 371 of 700 | Sultan
# Processing Record 372 of 700 | Strabane
# Processing Record 373 of 700 | Scottsbluff
# Processing Record 374 of 700 | Streetsboro
# Processing Record 375 of 700 | Rouyn-Noranda
# Processing Record 376 of 700 | Springfield
# Processing Record 377 of 700 | Koutiala
# Processing Record 378 of 700 | Honiara
# Processing Record 379 of 700 | Nagoya
# Processing Record 380 of 700 | Slatina
# Processing Record 381 of 700 | Buta
# Processing Record 382 of 700 | Steelton
# Processing Record 383 of 700 | Paraíso
# Processing Record 384 of 700 | Farragut
# Processing Record 385 of 700 | Kaliningrad
# Processing Record 386 of 700 | Nuevo Laredo
# Processing Record 387 of 700 | Oak Lawn
# Processing Record 388 of 700 | Barysaw
# Processing Record 389 of 700 | Ohrid
# Processing Record 390 of 700 | Broadway
# Processing Record 391 of 700 | Parnaíba
# Processing Record 392 of 700 | Madīnat ash Shamāl
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 393 of 700 | Ijevan
# Processing Record 394 of 700 | Breaux Bridge
# Processing Record 395 of 700 | Northport
# Processing Record 396 of 700 | Kudahuvadhoo
# Processing Record 397 of 700 | Louga
# Processing Record 398 of 700 | Vizianagaram
# Processing Record 399 of 700 | Pleasant Hill
# Processing Record 400 of 700 | Fort Wellington
# Processing Record 401 of 700 | Belmont
# Processing Record 402 of 700 | Dawson City
# Processing Record 403 of 700 | Berrien Springs
# Processing Record 404 of 700 | Hutchinson
# Processing Record 405 of 700 | Castello
# Processing Record 406 of 700 | Sharan
# Processing Record 407 of 700 | Hibbing
# Processing Record 408 of 700 | Grosse Pointe Farms
# Processing Record 409 of 700 | Dhuusa Mareeb
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 410 of 700 | Roscoe
# Processing Record 411 of 700 | Tocache
# Processing Record 412 of 700 | Odžaci
# Processing Record 413 of 700 | Cabanatuan
# Processing Record 414 of 700 | Puerto Quijarro
# Processing Record 415 of 700 | Anadyr
# Processing Record 416 of 700 | Sweet Home
# Processing Record 417 of 700 | I-n-Amenas
# Processing Record 418 of 700 | Kolda
# Processing Record 419 of 700 | New York
# Processing Record 420 of 700 | Itambé
# Processing Record 421 of 700 | West Chester
# Processing Record 422 of 700 | Valjevo
# Processing Record 423 of 700 | Andover
# Processing Record 424 of 700 | Perth Amboy
# Processing Record 425 of 700 | Wilmington
# Processing Record 426 of 700 | Phongsali
# Processing Record 427 of 700 | Washington
# Processing Record 428 of 700 | Inkster
# Processing Record 429 of 700 | Bol
# Processing Record 430 of 700 | Yulin
# Processing Record 431 of 700 | Vị Thanh
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 432 of 700 | Urgentch
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 433 of 700 | Kuala Lumpur
# Processing Record 434 of 700 | Carol Stream
# Processing Record 435 of 700 | Eden
# Processing Record 436 of 700 | Riverside
# Processing Record 437 of 700 | Changde
# Processing Record 438 of 700 | Sennar
# Processing Record 439 of 700 | Kırıkkale
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 440 of 700 | Avon
# Processing Record 441 of 700 | Lysychansk
# Processing Record 442 of 700 | Broadview
# Processing Record 443 of 700 | Gahanna
# Processing Record 444 of 700 | Sopron
# Processing Record 445 of 700 | Woods Cross
# Processing Record 446 of 700 | Poteau
# Processing Record 447 of 700 | London
# Processing Record 448 of 700 | Shar
# Processing Record 449 of 700 | Haikou
# Processing Record 450 of 700 | Cliffside Park
# Processing Record 451 of 700 | Penn Yan
# Processing Record 452 of 700 | Upper Arlington
# Processing Record 453 of 700 | Kannapolis
# Processing Record 454 of 700 | Ellenville
# Processing Record 455 of 700 | Angoche
# Processing Record 456 of 700 | Ozurgeti
# Processing Record 457 of 700 | Berane
# Processing Record 458 of 700 | Mbale
# Processing Record 459 of 700 | East Lansing
# Processing Record 460 of 700 | Sumqayt
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 461 of 700 | Madisonville
# Processing Record 462 of 700 | Yichang
# Processing Record 463 of 700 | Etawah
# Processing Record 464 of 700 | Araranguá
# Processing Record 465 of 700 | Columbia Falls
# Processing Record 466 of 700 | Wrocław
# Processing Record 467 of 700 | Kiambu
# Processing Record 468 of 700 | Mounds View
# Processing Record 469 of 700 | Wexford
# Processing Record 470 of 700 | Rincon
# Processing Record 471 of 700 | Tiksi
# Processing Record 472 of 700 | Terre Haute
# Processing Record 473 of 700 | Brentwood
# Processing Record 474 of 700 | Holland
# Processing Record 475 of 700 | Dobrova
# Processing Record 476 of 700 | Huntington Park
# Processing Record 477 of 700 | Wake Forest
# Processing Record 478 of 700 | Langfang
# Processing Record 479 of 700 | Indore
# Processing Record 480 of 700 | Natashquan
# Processing Record 481 of 700 | Senatobia
# Processing Record 482 of 700 | Valandovo
# Processing Record 483 of 700 | Targovishte
# Processing Record 484 of 700 | Kiryandongo
# Processing Record 485 of 700 | Fort Resolution
# Processing Record 486 of 700 | Rače
# Processing Record 487 of 700 | Kitgum
# Processing Record 488 of 700 | Merthyr Tudful
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 489 of 700 | Pembroke Park
# Processing Record 490 of 700 | Jordan
# Processing Record 491 of 700 | Quezon City
# Processing Record 492 of 700 | Navotas
# Processing Record 493 of 700 | Charles Town
# Processing Record 494 of 700 | Jundiaí
# Processing Record 495 of 700 | Fallon
# Processing Record 496 of 700 | Wamba
# Processing Record 497 of 700 | Castelo Branco
# Processing Record 498 of 700 | Fort-de-France
# Processing Record 499 of 700 | Mountain View
# Processing Record 500 of 700 | New Philadelphia
# Processing Record 501 of 700 | Columbia
# Processing Record 502 of 700 | Kpalimé
# Processing Record 503 of 700 | Lake Placid
# Processing Record 504 of 700 | Samux
# Processing Record 505 of 700 | Winnemucca
# Processing Record 506 of 700 | Žabljak
# Processing Record 507 of 700 | La Cruz
# Processing Record 508 of 700 | Myeik
# Processing Record 509 of 700 | Crossett
# Processing Record 510 of 700 | Marsaxlokk
# Processing Record 511 of 700 | Białystok
# Processing Record 512 of 700 | Bern
# Processing Record 513 of 700 | Itapeva
# Processing Record 514 of 700 | Destin
# Processing Record 515 of 700 | Fountain Valley
# Processing Record 516 of 700 | Seminole
# Processing Record 517 of 700 | Tadjoura
# Processing Record 518 of 700 | Kalyan
# Processing Record 519 of 700 | Ingleside
# Processing Record 520 of 700 | Karusi
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 521 of 700 | Oviedo
# Processing Record 522 of 700 | Valparaiso
# Processing Record 523 of 700 | Savoy
# Processing Record 524 of 700 | Niterói
# Processing Record 525 of 700 | Chukai
# Processing Record 526 of 700 | Union Beach
# Processing Record 527 of 700 | Baldwinsville
# Processing Record 528 of 700 | Cheney
# Processing Record 529 of 700 | Rivas
# Processing Record 530 of 700 | Dikson
# Processing Record 531 of 700 | Kasane
# Processing Record 532 of 700 | Vipava
# Processing Record 533 of 700 | Rock Falls
# Processing Record 534 of 700 | Nikopol
# Processing Record 535 of 700 | Hillsboro
# Processing Record 536 of 700 | Montana
# Processing Record 537 of 700 | Corumbá
# Processing Record 538 of 700 | Stokesdale
# Processing Record 539 of 700 | Xinqing
# Processing Record 540 of 700 | Iraklio
# Processing Record 541 of 700 | Taichung
# Processing Record 542 of 700 | Makhachkala
# Processing Record 543 of 700 | Montpellier
# Processing Record 544 of 700 | Truckee
# Processing Record 545 of 700 | Cheremkhovo
# Processing Record 546 of 700 | Valparai
# Processing Record 547 of 700 | Spearfish
# Processing Record 548 of 700 | Du Quoin
# Processing Record 549 of 700 | Fairmont
# Processing Record 550 of 700 | Deyang
# Processing Record 551 of 700 | Indianola
# Processing Record 552 of 700 | Kōchi
# Processing Record 553 of 700 | Ciudad Guzman
# Processing Record 554 of 700 | Johnsburg
# Processing Record 555 of 700 | Jesup
# Processing Record 556 of 700 | Espungabera
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 557 of 700 | Caracas
# Processing Record 558 of 700 | Valley
# Processing Record 559 of 700 | Cortez
# Processing Record 560 of 700 | Mamushë
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 561 of 700 | Wilkinsburg
# Processing Record 562 of 700 | Rowlett
# Processing Record 563 of 700 | Kaniama
# Processing Record 564 of 700 | Hiawatha
# Processing Record 565 of 700 | Falmouth
# Processing Record 566 of 700 | Debre Birhan
# Processing Record 567 of 700 | Vegreville
# Processing Record 568 of 700 | Starše
# Processing Record 569 of 700 | Wetumpka
# Processing Record 570 of 700 | Kohima
# Processing Record 571 of 700 | Jackson
# Processing Record 572 of 700 | Kirkland
# Processing Record 573 of 700 | Mount Arlington
# Processing Record 574 of 700 | Izhevsk
# Processing Record 575 of 700 | Princeton
# Processing Record 576 of 700 | Pilibhit
# Processing Record 577 of 700 | Oriximiná
# Processing Record 578 of 700 | Westlake
# Processing Record 579 of 700 | Pećinci
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 580 of 700 | Ağsu
# Processing Record 581 of 700 | Citrus Heights
# Processing Record 582 of 700 | Şūr
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 583 of 700 | Downers Grove
# Processing Record 584 of 700 | Linyi
# Processing Record 585 of 700 | Chitungwiza
# Processing Record 586 of 700 | São Tomé
# Processing Record 587 of 700 | Lebanon
# Processing Record 588 of 700 | Jaipur
# Processing Record 589 of 700 | Puerto Berrío
# Processing Record 590 of 700 | Cuyahoga Falls
# Processing Record 591 of 700 | Oil City
# Processing Record 592 of 700 | Fort Scott
# Processing Record 593 of 700 | Maryville
# Processing Record 594 of 700 | Red Oak
# Processing Record 595 of 700 | Kaser
# Processing Record 596 of 700 | Tirunelveli
# Processing Record 597 of 700 | Vranje
# Processing Record 598 of 700 | Shumen
# Processing Record 599 of 700 | Matthews
# Processing Record 600 of 700 | Nhlangano
# Processing Record 601 of 700 | Centralia
# Processing Record 602 of 700 | Craigavon
# Processing Record 603 of 700 | Bamako
# Processing Record 604 of 700 | Fernandópolis
# Processing Record 605 of 700 | Esperanza
# Processing Record 606 of 700 | Lynbrook
# Processing Record 607 of 700 | Mūrmuiža
# Processing Record 608 of 700 | Shijianzhuang
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 609 of 700 | Saint-Étienne
# Processing Record 610 of 700 | Puerto Williams
# Processing Record 611 of 700 | Gijón
# Processing Record 612 of 700 | Wilmette
# Processing Record 613 of 700 | Jersey Shore
# Processing Record 614 of 700 | Irbil
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 615 of 700 | Bellevue
# Processing Record 616 of 700 | Apopka
# Processing Record 617 of 700 | McFarland
# Processing Record 618 of 700 | Lilburn
# Processing Record 619 of 700 | Dunhua
# Processing Record 620 of 700 | Wagin
# Processing Record 621 of 700 | Armavir
# Processing Record 622 of 700 | Shafter
# Processing Record 623 of 700 | Decatur
# Processing Record 624 of 700 | Kaka
# Processing Record 625 of 700 | Mwaro
# Processing Record 626 of 700 | Siem Reap
# Processing Record 627 of 700 | Saginaw
# Processing Record 628 of 700 | Ordino
# Processing Record 629 of 700 | Converse
# Processing Record 630 of 700 | San José del Guaviare
# Processing Record 631 of 700 | Chikwawa
# Processing Record 632 of 700 | Celeken
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 633 of 700 | Mount Pleasant
# Processing Record 634 of 700 | Ta Khmau
# Processing Record 635 of 700 | Three Rivers
# Processing Record 636 of 700 | Lowell
# Processing Record 637 of 700 | Eastmain
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 638 of 700 | Shamva
# Processing Record 639 of 700 | Omolon
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 640 of 700 | Pineville
# Processing Record 641 of 700 | Laurinburg
# Processing Record 642 of 700 | Moatize
# Processing Record 643 of 700 | La Habra
# Processing Record 644 of 700 | Shimanovsk
# Processing Record 645 of 700 | Spokane Valley
# Processing Record 646 of 700 | Batna
# Processing Record 647 of 700 | Little Rock
# Processing Record 648 of 700 | Phoenixville
# Processing Record 649 of 700 | Madison
# Processing Record 650 of 700 | Cookeville
# Processing Record 651 of 700 | Pančevo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 652 of 700 | Fairview
# Processing Record 653 of 700 | Raymore
# Processing Record 654 of 700 | Anenii Noi
# Processing Record 655 of 700 | Ellsworth
# Processing Record 656 of 700 | Hagere Hiywet
# Processing Record 657 of 700 | Surat Thani
# Processing Record 658 of 700 | American Canyon
# Processing Record 659 of 700 | Monessen
# Processing Record 660 of 700 | Arta
# Processing Record 661 of 700 | Mažeikiai
# Processing Record 662 of 700 | East Bethel
# Processing Record 663 of 700 | Great Neck
# Processing Record 664 of 700 | Buon Me Thuot
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 665 of 700 | Pol-e Khomri
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 666 of 700 | Burlington
# Processing Record 667 of 700 | Vine Grove
# Processing Record 668 of 700 | Tatarsk
# Processing Record 669 of 700 | Maquoketa
# Processing Record 670 of 700 | Baxter
# Processing Record 671 of 700 | Chimbote
# Processing Record 672 of 700 | Xiangfan
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 673 of 700 | Alpine
# Processing Record 674 of 700 | Caribou
# Processing Record 675 of 700 | Sheridan
# Processing Record 676 of 700 | Gorenja Vas
# Processing Record 677 of 700 | Gibsonville
# Processing Record 678 of 700 | Oturkpo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 679 of 700 | Vernal
# Processing Record 680 of 700 | Gaya
# Processing Record 681 of 700 | Honda
# Processing Record 682 of 700 | Mokronog
# Processing Record 683 of 700 | Taldyqorghan
# Processing Record 684 of 700 | Alappuzha
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 685 of 700 | Comallo
# Processing Record 686 of 700 | Benha
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 687 of 700 | Singa
# Processing Record 688 of 700 | Iowa Park
# Processing Record 689 of 700 | Saint Paul Park
# Processing Record 690 of 700 | Gurgaon
# Processing Record 691 of 700 | Beirut
# Processing Record 692 of 700 | Stoke
# Processing Record 693 of 700 | Merrillville
# Processing Record 694 of 700 | Moscow
# Processing Record 695 of 700 | Lynn
# Processing Record 696 of 700 | Shkodër
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 697 of 700 | Osório
# Processing Record 698 of 700 | Mechanicville
# Processing Record 699 of 700 | Port Morant
# Processing Record 700 of 700 | Chino

# %%
name
# Out:
# ['rasht',
#  'karachi',
#  'gaborone',
#  'dunedin',
#  'reims',
#  'vijayawada',
#  'brindisi',
#  'corbin',
#  'midlothian',
#  'sveti nikole',
#  'yalutorovsk',
#  'buffalo grove',
#  'milton',
#  'alenquer',
#  'fredericksburg',
#  'cibitoke',
#  'omak',
#  'santa ana',
#  'dimitrovgrad',
#  'wellington',
#  'usakos',
#  'bremerhaven',
#  'king city',
#  'tunuyán',
#  'sarnia',
#  'warwick',
#  'itacoatiara',
#  'lynwood',
#  'forrest city',
#  'bairnsdale',
#  'mtwara',
#  'hopkins',
#  'royal palm beach',
#  'wiltz',
#  'elk grove',
#  'roseville',
#  'warwick',
#  'statesville',
#  'fair haven',
#  'hanahan',
#  'truro',
#  'somerdale',
#  'kiselevsk',
#  'toppenish',
#  'north chicago',
#  'halmstad',
#  'la mirada',
#  'wyomissing',
#  'millbrook',
#  'holdrege',
#  'bristol',
#  'youngtown',
#  'rečica ob savinji',
#  'cape coast',
#  'alert',
#  'tulcán',
#  'juan aldama',
#  'kota',
#  'pinole',
#  'kenora',
#  'fraser',
#  'uzhur',
#  'eindhoven',
#  'wilsonville',
#  'gwadar',
#  'bogoroditsk',
#  'nogales',
#  'gladstone',
#  'farmington hills',
#  'murray',
#  'wanaque',
#  'pendleton',
#  'abaí',
#  'san quintín',
#  'barinas',
#  'porbandar',
#  'acaraú',
#  'terrell',
#  'marovoay',
#  'klyuchi',
#  'north bend',
#  'black river',
#  'des peres',
#  'anshan',
#  'port macquarie',
#  'saveh',
#  'newcastle',
#  'lake city',
#  'lubbock',
#  'cape girardeau',
#  'palm beach',
#  'mwanza',
#  'superior',
#  'naval',
#  'chivilcoy',
#  'lishui',
#  'az zawiyah',
#  'poplar',
#  'dolneni',
#  'karasuk',
#  'manassas',
#  'northampton',
#  'brăila',
#  'zaporizhzhya',
#  'mcminns lagoon',
#  'hermiston',
#  'minsk',
#  'springfield',
#  'sevnica',
#  'majene',
#  'echuca',
#  'plattsburgh',
#  'corner brook',
#  'helena',
#  'lobamba',
#  'limbaži',
#  'buchans',
#  'pazin',
#  'kipili',
#  'derzhavinsk',
#  'voronezh',
#  'forest lake',
#  'mostaganem',
#  'llallagua',
#  'maintirano',
#  'sabanalarga',
#  'pala',
#  'slovenske konjice',
#  'linton',
#  'prineville',
#  'bridgeport',
#  'shakhty',
#  'san felipe',
#  'orillia',
#  'shadrinsk',
#  'monroe',
#  'conshohocken',
#  'chumbicha',
#  'ghanzi',
#  'broussard',
#  'west lafayette',
#  'santiago tuxtla',
#  'dalaba',
#  'sparks',
#  'bonita springs',
#  'ashland',
#  'ajmer',
#  'chester',
#  'davao',
#  'penola',
#  'karasburg',
#  'lambeth',
#  'ar rutbah',
#  'newtownabbey',
#  'margate',
#  'clermont-ferrand',
#  'logansport',
#  'yantai',
#  'mentor',
#  'petrópolis',
#  'ridley park',
#  'matam',
#  'san lorenzo',
#  'botucatu',
#  'new martinsville',
#  'albany',
#  'polokwane',
#  'mersin',
#  'bắc ninh',
#  'apatity',
#  'indio',
#  'los gatos',
#  'miass',
#  'zelenokumsk',
#  'gitarama',
#  'hengshui',
#  'aral',
#  'paw paw',
#  'owando',
#  'kakinada',
#  'athens',
#  'leeds',
#  'darwin',
#  'ptuj',
#  'ulaan-uul',
#  'matsumoto',
#  'mejillones',
#  'kassala',
#  'barcelos',
#  'novato',
#  'goodyear',
#  'somerville',
#  'fort mill',
#  'lahad datu',
#  'chicksands',
#  'glenwood springs',
#  'hawthorne',
#  'alexandria',
#  'poggio di chiesanuova',
#  'chalkida',
#  'alibunar',
#  'nadym',
#  'mwingi',
#  'palos hills',
#  'bonn',
#  'aguascalientes',
#  'fairport',
#  'ayr',
#  'conneaut',
#  'longview',
#  'maidenhead',
#  'marsabit',
#  'salamanca',
#  'shelburne',
#  'pativilca',
#  'imperatriz',
#  'fostoria',
#  'lwengo',
#  'butler',
#  'għasri',
#  'baydhabo',
#  'quaraí',
#  'hackensack',
#  'dalian',
#  'palangkaraya',
#  'linfen',
#  'ilford',
#  'chester',
#  'aurora',
#  'kollam',
#  'pagėgiai',
#  'kalachinsk',
#  'annecy',
#  'san justo',
#  'great bend',
#  'peterborough',
#  'kiel',
#  'farim',
#  'ugolnye kopi',
#  'orhei',
#  'donetsk',
#  'sremska mitrovica',
#  'sobral',
#  'maastricht',
#  'bougouni',
#  'malayer',
#  'sikar',
#  'shamkor',
#  'vorontsovo',
#  'millersville',
#  'río bueno',
#  'puerto deseado',
#  'assis',
#  'churchill',
#  'lovington',
#  'florianópolis',
#  'anniston',
#  'eagle mountain',
#  'fairlawn',
#  'ōita',
#  'newark',
#  'mons',
#  'golfito',
#  'alexandria',
#  'cotati',
#  'avon',
#  'south daytona',
#  'selfoss',
#  'three springs',
#  'stari trg pri ložu',
#  'little current',
#  'strongsville',
#  'koulamoutou',
#  'weyburn',
#  'kuopio',
#  'melrose park',
#  'herkimer',
#  'hola',
#  'duquesne',
#  'nova varoš',
#  'monroe',
#  'khorugh',
#  'los lagos',
#  'doljevac',
#  'panshi',
#  'galt',
#  'pembroke',
#  'el cerrito',
#  'bollnäs',
#  'taiyuan',
#  'oelwein',
#  'beipiao',
#  'russells point',
#  'prince george',
#  'fairview park',
#  'chickasaw',
#  'macenta',
#  'fayetteville',
#  'smederevska palanka',
#  'rockdale',
#  'qalat',
#  'san antonio de los baños',
#  'sebring',
#  'yakima',
#  'long beach',
#  'milwaukie',
#  'denpasar',
#  'voinjama',
#  'tillabéri',
#  'kapuskasing',
#  'havre',
#  'sarnen',
#  'shuozhou',
#  'west point',
#  'whiteville',
#  'highwood',
#  'san antonio',
#  'the hague',
#  'krško',
#  'kalbarri',
#  'madang',
#  'milton',
#  'vasilevo',
#  'ragana',
#  'flint',
#  'stavanger',
#  'digby',
#  'izmayil',
#  'guanare',
#  'muskego',
#  'auce',
#  'port hardy',
#  'worth',
#  'mount airy',
#  'jima',
#  'bawku',
#  'ladue',
#  'urbana',
#  'katy',
#  'pune',
#  'bolu',
#  'sultan',
#  'strabane',
#  'scottsbluff',
#  'streetsboro',
#  'rouyn-noranda',
#  'springfield',
#  'koutiala',
#  'honiara',
#  'nagoya',
#  'slatina',
#  'buta',
#  'steelton',
#  'paraíso',
#  'farragut',
#  'kaliningrad',
#  'nuevo laredo',
#  'oak lawn',
#  'barysaw',
#  'ohrid',
#  'broadway',
#  'parnaíba',
#  'ijevan',
#  'breaux bridge',
#  'northport',
#  'kudahuvadhoo',
#  'louga',
#  'vizianagaram',
#  'pleasant hill',
#  'fort wellington',
#  'belmont',
#  'dawson city',
#  'berrien springs',
#  'hutchinson',
#  'castello',
#  'sharan',
#  'hibbing',
#  'grosse pointe farms',
#  'roscoe',
#  'tocache',
#  'odžaci',
#  'cabanatuan',
#  'puerto quijarro',
#  'anadyr',
#  'sweet home',
#  'i-n-amenas',
#  'kolda',
#  'new york',
#  'itambé',
#  'west chester',
#  'valjevo',
#  'andover',
#  'perth amboy',
#  'wilmington',
#  'phongsali',
#  'washington dc.',
#  'inkster',
#  'bol',
#  'yulin',
#  'kuala lumpur',
#  'carol stream',
#  'eden',
#  'riverside',
#  'changde',
#  'sennar',
#  'avon',
#  'lysychansk',
#  'broadview',
#  'gahanna',
#  'sopron',
#  'woods cross',
#  'poteau',
#  'london',
#  'shar',
#  'haikou',
#  'cliffside park',
#  'penn yan',
#  'upper arlington',
#  'kannapolis',
#  'ellenville',
#  'angoche',
#  'ozurgeti',
#  'berane',
#  'mbale',
#  'east lansing',
#  'madisonville',
#  'yichang',
#  'etawah',
#  'araranguá',
#  'columbia falls',
#  'wrocław',
#  'kiambu',
#  'mounds view',
#  'wexford',
#  'rincon',
#  'tiksi',
#  'terre haute',
#  'brentwood',
#  'holland',
#  'dobrova',
#  'huntington park',
#  'wake forest',
#  'langfang',
#  'indore',
#  'natashquan',
#  'senatobia',
#  'valandovo',
#  'targovishte',
#  'kiryandongo',
#  'fort resolution',
#  'rače',
#  'kitgum',
#  'pembroke park',
#  'jordan',
#  'quezon city',
#  'navotas',
#  'charles town',
#  'jundiaí',
#  'fallon',
#  'wamba',
#  'castelo branco',
#  'fort-de-france',
#  'mountain view',
#  'new philadelphia',
#  'columbia',
#  'kpalimé',
#  'lake placid',
#  'samux',
#  'winnemucca',
#  'žabljak',
#  'la cruz',
#  'myeik',
#  'crossett',
#  'marsaxlokk',
#  'białystok',
#  'bern',
#  'itapeva',
#  'destin',
#  'fountain valley',
#  'seminole',
#  'tadjoura',
#  'kalyan',
#  'ingleside',
#  'oviedo',
#  'valparaiso',
#  'savoy',
#  'niterói',
#  'chukai',
#  'union beach',
#  'baldwinsville',
#  'cheney',
#  'rivas',
#  'dikson',
#  'kasane',
#  'vipava',
#  'rock falls',
#  'nikopol',
#  'hillsboro',
#  'montana',
#  'corumba',
#  'stokesdale',
#  'xinqing',
#  'iraklio',
#  'taichung',
#  'makhachkala',
#  'montpellier',
#  'truckee',
#  'cheremkhovo',
#  'valparai',
#  'spearfish',
#  'du quoin',
#  'fairmont',
#  'deyang',
#  'indianola',
#  'kōchi',
#  'ciudad guzman',
#  'johnsburg',
#  'jesup',
#  'caracas',
#  'valley',
#  'cortez',
#  'wilkinsburg',
#  'rowlett',
#  'kaniama',
#  'hiawatha',
#  'falmouth',
#  'debre birhan',
#  'vegreville',
#  'starše',
#  'wetumpka',
#  'kohima',
#  'jackson',
#  'kirkland',
#  'mount arlington',
#  'izhevsk',
#  'princeton',
#  'pilibhit',
#  'oriximiná',
#  'westlake',
#  'ağsu',
#  'citrus heights',
#  'downers grove',
#  'linyi',
#  'chitungwiza',
#  'são tomé',
#  'lebanon',
#  'jaipur',
#  'puerto berrío',
#  'cuyahoga falls',
#  'oil city',
#  'fort scott',
#  'maryville',
#  'red oak',
#  'kaser',
#  'tirunelveli',
#  'vranje',
#  'shumen',
#  'matthews',
#  'nhlangano',
#  'centralia',
#  'craigavon',
#  'bamako',
#  'fernandópolis',
#  'esperanza',
#  'lynbrook',
#  'mūrmuiža',
#  'saint-étienne',
#  'puerto williams',
#  'gijón',
#  'wilmette',
#  'jersey shore',
#  'bellevue',
#  'apopka',
#  'mcfarland',
#  'lilburn',
#  'dunhua',
#  'wagin',
#  'armavir',
#  'shafter',
#  'decatur',
#  'kaka',
#  'mwaro',
#  'siem reap',
#  'saginaw',
#  'ordino',
#  'converse',
#  'san josé del guaviare',
#  'chikwawa',
#  'mount pleasant',
#  'ta khmau',
#  'three rivers',
#  'lowell',
#  'shamva',
#  'pineville',
#  'laurinburg',
#  'moatize',
#  'la habra',
#  'shimanovsk',
#  'spokane valley',
#  'batna',
#  'little rock',
#  'phoenixville',
#  'madison',
#  'cookeville',
#  'fairview',
#  'raymore',
#  'anenii noi',
#  'ellsworth',
#  'hagere hiywet',
#  'surat thani',
#  'american canyon',
#  'monessen',
#  'arta',
#  'mažeikiai',
#  'east bethel',
#  'great neck',
#  'burlington',
#  'vine grove',
#  'tatarsk',
#  'maquoketa',
#  'baxter',
#  'chimbote',
#  'alpine',
#  'caribou',
#  'sheridan',
#  'gorenja vas',
#  'gibsonville',
#  'vernal',
#  'gaya',
#  'honda',
#  'mokronog',
#  'taldyqorghan',
#  'comallo',
#  'singa',
#  'iowa park',
#  'saint paul park',
#  'gurgaon',
#  'beirut',
#  'stoke',
#  'merrillville',
#  'moscow',
#  'lynn',
#  'osório',
#  'mechanicville',
#  'port morant',
#  'chino']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a dictionary from the raw data
raw_weather_data = {"City": name,
                   "Cloudiness": clouds,
                   "Date": date,
                   "Humidity": humidity,
                   "Max Temp": temp_max,
                   "Wind Speed": wind_speed}

# %%
#create a datafram from the dictionary
weather_data = pd.DataFrame(raw_weather_data)

# %%
#merge the dataframe with the lats and longs with the dataframe with the weather information
#city_weather_data = pd.merge(weather_data,random_cities, on="city")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Max Temp"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Max Temperature ({now.month}/{now.day}/{now.year})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig('LatvsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Humidity"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Humidity ({now.month}/{now.day}/{now.year})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsHumid.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Cloudiness"]
plt.xlim(-60,80)
plt.ylim(0,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Cloudiness ({now.month}/{now.day}/{now.year})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Wind Speed"]
plt.xlim(-60,80)
plt.ylim(0,30)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Wind Speed ({now.month}/{now.day}/{now.year})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.savefig('LatvsWind.png')
plt.show()
