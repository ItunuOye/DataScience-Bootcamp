# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
#
# There were few observable trends that I noticed.
#
# First it seems like most of the weather output were varied but more in the Northern hemipshere. This is as a result of the weather changes and the time of the year.
#
# The maximum temperatures are concentrated in the northern hemisphere and this is because there is more population in the northern hemisphere and thus more cities.
#
# Humidity is concentrated in the temperate to tropical regions and more so in the northern hemisphere.
#
# Bonus: There is a weird pattern in the cloudiness plot and I am not sure what it means.

# %% [markdown]
# ## Generate Cities List

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime


now = datetime.datetime.now()

# %%
# Import API key
from api_keys import api_key

# %%
# Output File (CSV)
citi_list = pd.read_csv("worldcities.csv")

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Choose a random sample of 100 cities
random_cities = citi_list.sample(n=700)

# %%
#view dataframe of random cities
random_cities.head()
# Out:
#            city city_ascii      lat       lng        country iso2 iso3  \
# 5811       Dali       Dali  34.7953  109.9378          China   CN  CHN
# 12555    Salina     Salina  38.8143  -97.6151  United States   US  USA
# 5131   Nokaneng   Nokaneng -19.6696   22.2700       Botswana   BW  BWA
# 11521    Bisbee     Bisbee  31.4126 -109.9179  United States   US  USA
# 12747  Edgewood   Edgewood  39.0091  -84.5604  United States   US  USA
#
#       admin_name capital  population          id
# 5811     Shaanxi   minor    109696.0  1156708054
# 12555     Kansas     NaN     47123.0  1840001647
# 5131         NaN     NaN      1763.0  1072707427
# 11521    Arizona     NaN      5189.0  1840019495
# 12747   Kentucky     NaN      8748.0  1840013166

# %%
#create a series of cities
citi_search_list = random_cities.city

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create a series of cities
city_search_list = random_cities.city

# %%
#create several lists to hold raw data
name = []
clouds = []
date = []
humidity = []
temp_max = []
wind_speed = []

#log the length of the series
list_len = len(city_search_list)

#specify the base url
url = "http://api.openweathermap.org/data/2.5/weather?"

#set the measurement system
units = "imperial"

#initialize a variable for the record count
record_cnt = 1

#create a loop to get the information for all the cities and add them to the lists
#also add error handling
for city in city_search_list:
    print(f"Processing Record {record_cnt} of {list_len} | {city}")
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    response = requests.get(query_url).json()
    
    try:
        name.append(response["name"].lower())
    except KeyError:
        print("key is missing")
        
    try:
        clouds.append(response["clouds"]["all"])
    except KeyError:
        print("key is missing")
            
    try:
        date.append(response["dt"])
    except KeyError:
        print("key is missing")
                
    try:
        humidity.append(response["main"]["humidity"])
    except KeyError:
        print("key is missing")
                    
    try:
        temp_max.append(response["main"]["temp_max"])
    except KeyError:
        print("key is missing")
                        
    try:
        wind_speed.append(response["wind"]["speed"])
    except KeyError:
        print("key is missing")
        
    #iterate the record count on each loop
    record_cnt = record_cnt + 1
# Out:
# Processing Record 1 of 700 | Dali
# Processing Record 2 of 700 | Salina
# Processing Record 3 of 700 | Nokaneng
# Processing Record 4 of 700 | Bisbee
# Processing Record 5 of 700 | Edgewood
# Processing Record 6 of 700 | Lynn Haven
# Processing Record 7 of 700 | Bosilegrad
# Processing Record 8 of 700 | Logashkino
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 9 of 700 | Masallı
# Processing Record 10 of 700 | Cali
# Processing Record 11 of 700 | West Point
# Processing Record 12 of 700 | Nautla
# Processing Record 13 of 700 | Richland
# Processing Record 14 of 700 | Lake Dallas
# Processing Record 15 of 700 | Koboko
# Processing Record 16 of 700 | Sydney
# Processing Record 17 of 700 | Rincon
# Processing Record 18 of 700 | Webster
# Processing Record 19 of 700 | Jim Thorpe
# Processing Record 20 of 700 | Miami Gardens
# Processing Record 21 of 700 | Warwick
# Processing Record 22 of 700 | Algeciras
# Processing Record 23 of 700 | Shelby
# Processing Record 24 of 700 | Makoua
# Processing Record 25 of 700 | Sokoto
# Processing Record 26 of 700 | Kenai
# Processing Record 27 of 700 | Larissa
# Processing Record 28 of 700 | Owosso
# Processing Record 29 of 700 | Waynesville
# Processing Record 30 of 700 | West Lafayette
# Processing Record 31 of 700 | Svolvær
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 32 of 700 | Yurga
# Processing Record 33 of 700 | Nevinnomyssk
# Processing Record 34 of 700 | Kajiado
# Processing Record 35 of 700 | Slinger
# Processing Record 36 of 700 | Ust Kamchatsk
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 37 of 700 | Rubirizi
# Processing Record 38 of 700 | Cirebon
# Processing Record 39 of 700 | Breese
# Processing Record 40 of 700 | Aspen
# Processing Record 41 of 700 | At Taif
# Processing Record 42 of 700 | Hudson Falls
# Processing Record 43 of 700 | Parras
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 44 of 700 | Tyrone
# Processing Record 45 of 700 | Bua Yai
# Processing Record 46 of 700 | Edéa
# Processing Record 47 of 700 | Masindi
# Processing Record 48 of 700 | Lorica
# Processing Record 49 of 700 | Sveta Ana v Slovenskih Goricah
# Processing Record 50 of 700 | Samux
# Processing Record 51 of 700 | Matara
# Processing Record 52 of 700 | Hisar
# Processing Record 53 of 700 | Januária
# Processing Record 54 of 700 | Bestobe
# Processing Record 55 of 700 | Għarb
# Processing Record 56 of 700 | Hotan
# Processing Record 57 of 700 | Uberlândia
# Processing Record 58 of 700 | Kearney
# Processing Record 59 of 700 | Tenkodogo
# Processing Record 60 of 700 | Pati
# Processing Record 61 of 700 | Cotonou
# Processing Record 62 of 700 | Tomsk
# Processing Record 63 of 700 | Lake Placid
# Processing Record 64 of 700 | Zimmerman
# Processing Record 65 of 700 | San Benito
# Processing Record 66 of 700 | Geneva
# Processing Record 67 of 700 | Pietermaritzburg
# Processing Record 68 of 700 | Caldera
# Processing Record 69 of 700 | Ishim
# Processing Record 70 of 700 | Tipasa
# Processing Record 71 of 700 | Pallisa
# Processing Record 72 of 700 | Tarin Kowt
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 73 of 700 | Osijek
# Processing Record 74 of 700 | Columbia
# Processing Record 75 of 700 | Talas
# Processing Record 76 of 700 | Sabinas Hidalgo
# Processing Record 77 of 700 | Nelson House
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 78 of 700 | Tillamook
# Processing Record 79 of 700 | Honolulu
# Processing Record 80 of 700 | Saint Helens
# Processing Record 81 of 700 | Mananjary
# Processing Record 82 of 700 | Oum el Bouaghi
# Processing Record 83 of 700 | Macas
# Processing Record 84 of 700 | Bethany
# Processing Record 85 of 700 | Gdańsk
# Processing Record 86 of 700 | Saskatoon
# Processing Record 87 of 700 | Berkeley
# Processing Record 88 of 700 | DeRidder
# Processing Record 89 of 700 | Brockville
# Processing Record 90 of 700 | Fengjie
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 91 of 700 | Ondo
# Processing Record 92 of 700 | Ralston
# Processing Record 93 of 700 | Wilkinsburg
# Processing Record 94 of 700 | Prosperidad
# Processing Record 95 of 700 | Bossangoa
# Processing Record 96 of 700 | Lovec
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 97 of 700 | Valença
# Processing Record 98 of 700 | Schefferville
# Processing Record 99 of 700 | Khaskovo
# Processing Record 100 of 700 | Asela
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 101 of 700 | Queen Creek
# Processing Record 102 of 700 | Beitbridge
# Processing Record 103 of 700 | Clinton
# Processing Record 104 of 700 | Patiala
# Processing Record 105 of 700 | Farmington
# Processing Record 106 of 700 | Portsmouth
# Processing Record 107 of 700 | Dallas
# Processing Record 108 of 700 | Santa Clara
# Processing Record 109 of 700 | Klaipėda
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 110 of 700 | Oakdale
# Processing Record 111 of 700 | Mansfield
# Processing Record 112 of 700 | Cilacap
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 113 of 700 | Midvale
# Processing Record 114 of 700 | Windcrest
# Processing Record 115 of 700 | Vadodara
# Processing Record 116 of 700 | Mentor-on-the-Lake
# Processing Record 117 of 700 | Wheaton
# Processing Record 118 of 700 | Rocky River
# Processing Record 119 of 700 | Beavercreek
# Processing Record 120 of 700 | Altus
# Processing Record 121 of 700 | Noblesville
# Processing Record 122 of 700 | En Nuhud
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 123 of 700 | Lạng Sơn
# Processing Record 124 of 700 | Fort Plain
# Processing Record 125 of 700 | Zgornja Kungota
# Processing Record 126 of 700 | Como
# Processing Record 127 of 700 | Mascara
# Processing Record 128 of 700 | Salamá
# Processing Record 129 of 700 | Nusaybin
# Processing Record 130 of 700 | Maykop
# Processing Record 131 of 700 | Dirj
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 132 of 700 | Alajuela
# Processing Record 133 of 700 | Rockford
# Processing Record 134 of 700 | Santiago
# Processing Record 135 of 700 | Hays
# Processing Record 136 of 700 | Coffeyville
# Processing Record 137 of 700 | Sant Julià de Lòria
# Processing Record 138 of 700 | Madona
# Processing Record 139 of 700 | Marka
# Processing Record 140 of 700 | Inowrocław
# Processing Record 141 of 700 | Lawrenceburg
# Processing Record 142 of 700 | Crawfordsville
# Processing Record 143 of 700 | Gingin
# Processing Record 144 of 700 | Mattoon
# Processing Record 145 of 700 | Sousse
# Processing Record 146 of 700 | Glen Cove
# Processing Record 147 of 700 | Beaver Falls
# Processing Record 148 of 700 | Tengchong
# Processing Record 149 of 700 | Rūjiena
# Processing Record 150 of 700 | Minden
# Processing Record 151 of 700 | Siġġiewi
# Processing Record 152 of 700 | Luuq
# Processing Record 153 of 700 | Glenolden
# Processing Record 154 of 700 | Kazan
# Processing Record 155 of 700 | Lake Charles
# Processing Record 156 of 700 | Sayreville
# Processing Record 157 of 700 | Rogers
# Processing Record 158 of 700 | Aveiro
# Processing Record 159 of 700 | Vác
# Processing Record 160 of 700 | La Grange
# Processing Record 161 of 700 | Andamooka
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 162 of 700 | Yogyakarta
# Processing Record 163 of 700 | Sinnamary
# Processing Record 164 of 700 | Newport
# Processing Record 165 of 700 | Höfn
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 166 of 700 | Larkana
# Processing Record 167 of 700 | Redwood City
# Processing Record 168 of 700 | Winter Haven
# Processing Record 169 of 700 | Keyser
# Processing Record 170 of 700 | Bedourie
# Processing Record 171 of 700 | Nabatiye et Tahta
# Processing Record 172 of 700 | Bonn
# Processing Record 173 of 700 | Aweil
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 174 of 700 | Rathdrum
# Processing Record 175 of 700 | Phan Thiet
# Processing Record 176 of 700 | Merimbula
# Processing Record 177 of 700 | Orwigsburg
# Processing Record 178 of 700 | Tartus
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 179 of 700 | Marshall
# Processing Record 180 of 700 | Sasovo
# Processing Record 181 of 700 | Vermilion
# Processing Record 182 of 700 | Willard
# Processing Record 183 of 700 | Benton
# Processing Record 184 of 700 | Plovdiv
# Processing Record 185 of 700 | Uray
# Processing Record 186 of 700 | Tauragė
# Processing Record 187 of 700 | Ossining
# Processing Record 188 of 700 | Camden
# Processing Record 189 of 700 | Ypacaraí
# Processing Record 190 of 700 | Kaliningrad
# Processing Record 191 of 700 | Lake Delton
# Processing Record 192 of 700 | Vestavia Hills
# Processing Record 193 of 700 | Birganj
# Processing Record 194 of 700 | Izaz
# Processing Record 195 of 700 | Evans
# Processing Record 196 of 700 | Tupelo
# Processing Record 197 of 700 | Rifle
# Processing Record 198 of 700 | Canby
# Processing Record 199 of 700 | Nikel
# Processing Record 200 of 700 | Dhule
# Processing Record 201 of 700 | Innsbruck
# Processing Record 202 of 700 | Florencia
# Processing Record 203 of 700 | Xocavənd
# Processing Record 204 of 700 | Cuyahoga Falls
# Processing Record 205 of 700 | Rodeo
# Processing Record 206 of 700 | Ascension
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 207 of 700 | Elizabeth
# Processing Record 208 of 700 | New Richmond
# Processing Record 209 of 700 | Agapa
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 210 of 700 | Merced
# Processing Record 211 of 700 | Tigoa
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 212 of 700 | Iba
# Processing Record 213 of 700 | Shalqar
# Processing Record 214 of 700 | Tskhinvali
# Processing Record 215 of 700 | Goose Creek
# Processing Record 216 of 700 | Rouen
# Processing Record 217 of 700 | Palana
# Processing Record 218 of 700 | Marília
# Processing Record 219 of 700 | Makamba
# Processing Record 220 of 700 | Yoro
# Processing Record 221 of 700 | Cojutepeque
# Processing Record 222 of 700 | Artashat
# Processing Record 223 of 700 | Odžaci
# Processing Record 224 of 700 | St.-Denis
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 225 of 700 | Rensselaer
# Processing Record 226 of 700 | Princeton
# Processing Record 227 of 700 | Banes
# Processing Record 228 of 700 | Bhopal
# Processing Record 229 of 700 | Tehuacan
# Processing Record 230 of 700 | Ismaïlia
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 231 of 700 | Plymouth
# Processing Record 232 of 700 | Želino
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 233 of 700 | Blytheville
# Processing Record 234 of 700 | Seneca
# Processing Record 235 of 700 | Deltona
# Processing Record 236 of 700 | Kafr el Sheikh
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 237 of 700 | Savannakhet
# Processing Record 238 of 700 | Andkhvoy
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 239 of 700 | Bərdə
# Processing Record 240 of 700 | Santa Monica
# Processing Record 241 of 700 | Lansing
# Processing Record 242 of 700 | Qui Nhon
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 243 of 700 | Pilsrundāle
# Processing Record 244 of 700 | Wigan
# Processing Record 245 of 700 | Ibarra
# Processing Record 246 of 700 | Nakhodka
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 247 of 700 | Morondava
# Processing Record 248 of 700 | Beaufort West
# Processing Record 249 of 700 | Veinticinco de Mayo
# Processing Record 250 of 700 | Charikar
# Processing Record 251 of 700 | Vaslui
# Processing Record 252 of 700 | Aventura
# Processing Record 253 of 700 | Clinton
# Processing Record 254 of 700 | Sanya
# Processing Record 255 of 700 | Purcellville
# Processing Record 256 of 700 | Pelham
# Processing Record 257 of 700 | Sapele
# Processing Record 258 of 700 | Lake Forest
# Processing Record 259 of 700 | Alamo Heights
# Processing Record 260 of 700 | Eugene
# Processing Record 261 of 700 | Jamalpur
# Processing Record 262 of 700 | Santa Rosa
# Processing Record 263 of 700 | El Minya
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 264 of 700 | Anlu
# Processing Record 265 of 700 | Vransko
# Processing Record 266 of 700 | Río Verde
# Processing Record 267 of 700 | Tamuín
# Processing Record 268 of 700 | Kilgore
# Processing Record 269 of 700 | Podolsk
# Processing Record 270 of 700 | Ngerulmud
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 271 of 700 | Chengdu
# Processing Record 272 of 700 | Sulphur Springs
# Processing Record 273 of 700 | Kibale
# Processing Record 274 of 700 | Ordino
# Processing Record 275 of 700 | Savanna-la-Mar
# Processing Record 276 of 700 | Mount Sterling
# Processing Record 277 of 700 | Silsbee
# Processing Record 278 of 700 | Drogheda
# Processing Record 279 of 700 | Leopoldina
# Processing Record 280 of 700 | Stickney
# Processing Record 281 of 700 | Beyla
# Processing Record 282 of 700 | Colonie
# Processing Record 283 of 700 | Blagoevgrad
# Processing Record 284 of 700 | Peabody
# Processing Record 285 of 700 | Natchitoches
# Processing Record 286 of 700 | Stockton
# Processing Record 287 of 700 | Mexia
# Processing Record 288 of 700 | Djenné
# Processing Record 289 of 700 | Williston Park
# Processing Record 290 of 700 | Great Bend
# Processing Record 291 of 700 | Guapi
# Processing Record 292 of 700 | Alice Springs
# Processing Record 293 of 700 | Samarqand
# Processing Record 294 of 700 | Auburn
# Processing Record 295 of 700 | Melton
# Processing Record 296 of 700 | Chillán
# Processing Record 297 of 700 | Kolpashevo
# Processing Record 298 of 700 | Qingdao
# Processing Record 299 of 700 | Košice
# Processing Record 300 of 700 | Shelbyville
# Processing Record 301 of 700 | Muang Xai
# Processing Record 302 of 700 | Jalapa
# Processing Record 303 of 700 | Dembi Dolo
# Processing Record 304 of 700 | Libreville
# Processing Record 305 of 700 | Liberec
# Processing Record 306 of 700 | Nazran
# Processing Record 307 of 700 | Darwin
# Processing Record 308 of 700 | Dalhart
# Processing Record 309 of 700 | St.-Brieuc
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 310 of 700 | Gallatin
# Processing Record 311 of 700 | Marion
# Processing Record 312 of 700 | Barranquilla
# Processing Record 313 of 700 | Wuwei
# Processing Record 314 of 700 | Buyende
# Processing Record 315 of 700 | Šentilj
# Processing Record 316 of 700 | Irmo
# Processing Record 317 of 700 | Hamilton
# Processing Record 318 of 700 | Fenton
# Processing Record 319 of 700 | Kristiansand
# Processing Record 320 of 700 | Apsheronsk
# Processing Record 321 of 700 | Nevyansk
# Processing Record 322 of 700 | Sokol
# Processing Record 323 of 700 | Ulanhot
# Processing Record 324 of 700 | Braidwood
# Processing Record 325 of 700 | Mill Valley
# Processing Record 326 of 700 | Brus
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 327 of 700 | Scone
# Processing Record 328 of 700 | McPherson
# Processing Record 329 of 700 | Aračinovo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 330 of 700 | Soubré
# Processing Record 331 of 700 | Whitehouse
# Processing Record 332 of 700 | Durham
# Processing Record 333 of 700 | Naypyidaw
# Processing Record 334 of 700 | Chelsea
# Processing Record 335 of 700 | Guadalajara
# Processing Record 336 of 700 | Zebulon
# Processing Record 337 of 700 | Cohoes
# Processing Record 338 of 700 | Balkanabat
# Processing Record 339 of 700 | Kidapawan
# Processing Record 340 of 700 | Guasave
# Processing Record 341 of 700 | Galion
# Processing Record 342 of 700 | Kilosa
# Processing Record 343 of 700 | Shiraz
# Processing Record 344 of 700 | Luebo
# Processing Record 345 of 700 | Nepalganj
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 346 of 700 | Muzaffarnagar
# Processing Record 347 of 700 | Pingree Grove
# Processing Record 348 of 700 | Taizhou
# Processing Record 349 of 700 | Tarrafal
# Processing Record 350 of 700 | Jiaohe
# Processing Record 351 of 700 | Tukchi
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 352 of 700 | West Bend
# Processing Record 353 of 700 | Bristol
# Processing Record 354 of 700 | Santiago de Compostela
# Processing Record 355 of 700 | Lilongwe
# Processing Record 356 of 700 | Auburndale
# Processing Record 357 of 700 | Chikwawa
# Processing Record 358 of 700 | Rahway
# Processing Record 359 of 700 | Preddvor
# Processing Record 360 of 700 | Balzers
# Processing Record 361 of 700 | Malargüe
# Processing Record 362 of 700 | Paraná
# Processing Record 363 of 700 | Greendale
# Processing Record 364 of 700 | Ayutla
# Processing Record 365 of 700 | Buena Vista
# Processing Record 366 of 700 | Posen
# Processing Record 367 of 700 | Hail
# Processing Record 368 of 700 | Embu
# Processing Record 369 of 700 | Dedza
# Processing Record 370 of 700 | Steamboat Springs
# Processing Record 371 of 700 | Puerto Pinasco
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 372 of 700 | Kenora
# Processing Record 373 of 700 | Tønsberg
# Processing Record 374 of 700 | Salatiga
# Processing Record 375 of 700 | Nieuw Nickerie
# Processing Record 376 of 700 | Warren
# Processing Record 377 of 700 | Mobile
# Processing Record 378 of 700 | Maizuru
# Processing Record 379 of 700 | Sokodé
# Processing Record 380 of 700 | Rostov
# Processing Record 381 of 700 | Birak
# Processing Record 382 of 700 | Dali
# Processing Record 383 of 700 | Endicott
# Processing Record 384 of 700 | Jaguarão
# Processing Record 385 of 700 | Log pri Brezovici
# Processing Record 386 of 700 | Georgetown
# Processing Record 387 of 700 | Shimoga
# Processing Record 388 of 700 | Beverly Hills
# Processing Record 389 of 700 | Abbotsford
# Processing Record 390 of 700 | Ed Daein
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 391 of 700 | Bueng Kan
# Processing Record 392 of 700 | Cobán
# Processing Record 393 of 700 | Upington
# Processing Record 394 of 700 | Paide
# Processing Record 395 of 700 | Mulhouse
# Processing Record 396 of 700 | Carthage
# Processing Record 397 of 700 | Harrison
# Processing Record 398 of 700 | Örebro
# Processing Record 399 of 700 | Burkburnett
# Processing Record 400 of 700 | Magway
# Processing Record 401 of 700 | Conway
# Processing Record 402 of 700 | Sellersburg
# Processing Record 403 of 700 | Plantation
# Processing Record 404 of 700 | Catford
# Processing Record 405 of 700 | Milton Keynes
# Processing Record 406 of 700 | Tieli
# Processing Record 407 of 700 | Mount Isa
# Processing Record 408 of 700 | Gornji Grad
# Processing Record 409 of 700 | Kingsford
# Processing Record 410 of 700 | Saint-Georges
# Processing Record 411 of 700 | Tega Cay
# Processing Record 412 of 700 | Arendal
# Processing Record 413 of 700 | Montemorelos
# Processing Record 414 of 700 | Manhattan
# Processing Record 415 of 700 | Fort Wright
# Processing Record 416 of 700 | Wilkes-Barre
# Processing Record 417 of 700 | Obihiro
# Processing Record 418 of 700 | Ulaangom
# Processing Record 419 of 700 | Willits
# Processing Record 420 of 700 | Clarinda
# Processing Record 421 of 700 | Nan
# Processing Record 422 of 700 | Ha Giang
# Processing Record 423 of 700 | Clifton Springs
# Processing Record 424 of 700 | London
# Processing Record 425 of 700 | Logatec
# Processing Record 426 of 700 | Monticello
# Processing Record 427 of 700 | Solčava
# Processing Record 428 of 700 | Caxias do Sul
# Processing Record 429 of 700 | Saga
# Processing Record 430 of 700 | Shippensburg
# Processing Record 431 of 700 | Amsterdam
# Processing Record 432 of 700 | Muldrow
# Processing Record 433 of 700 | Nova Friburgo
# Processing Record 434 of 700 | Freeport
# Processing Record 435 of 700 | Merošina
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 436 of 700 | Bhilai
# Processing Record 437 of 700 | Isingiro
# Processing Record 438 of 700 | Geneva
# Processing Record 439 of 700 | Monee
# Processing Record 440 of 700 | Greeneville
# Processing Record 441 of 700 | Dover
# Processing Record 442 of 700 | Halifax
# Processing Record 443 of 700 | Sawmills
# Processing Record 444 of 700 | Zhuozhou
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 445 of 700 | Eger
# Processing Record 446 of 700 | Akureyi
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 447 of 700 | Owensboro
# Processing Record 448 of 700 | Jena
# Processing Record 449 of 700 | Lawrence
# Processing Record 450 of 700 | Venice
# Processing Record 451 of 700 | Antsiranana
# Processing Record 452 of 700 | Sahuarita
# Processing Record 453 of 700 | Thatcher
# Processing Record 454 of 700 | Mazatlán
# Processing Record 455 of 700 | Türkmenabat
# Processing Record 456 of 700 | Chichester
# Processing Record 457 of 700 | Zhuzhou
# Processing Record 458 of 700 | Pretoria
# Processing Record 459 of 700 | Tall Afar
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 460 of 700 | Klagenfurt
# Processing Record 461 of 700 | Villa Rica
# Processing Record 462 of 700 | Bulungu
# Processing Record 463 of 700 | Boulder
# Processing Record 464 of 700 | Nelidovo
# Processing Record 465 of 700 | Tierra Amarilla
# Processing Record 466 of 700 | Sylacauga
# Processing Record 467 of 700 | Panama City Beach
# Processing Record 468 of 700 | Bikin
# Processing Record 469 of 700 | Grantsville
# Processing Record 470 of 700 | Saatlı
# Processing Record 471 of 700 | Pucallpa
# Processing Record 472 of 700 | Mollendo
# Processing Record 473 of 700 | Maanshan
# Processing Record 474 of 700 | Palembang
# Processing Record 475 of 700 | Biu
# Processing Record 476 of 700 | Dover
# Processing Record 477 of 700 | Butebo
# Processing Record 478 of 700 | West View
# Processing Record 479 of 700 | Lititz
# Processing Record 480 of 700 | Columbia
# Processing Record 481 of 700 | Sancti Spíritus
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 482 of 700 | Miracema
# Processing Record 483 of 700 | Gemena
# Processing Record 484 of 700 | Xigaze
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 485 of 700 | Desert Hot Springs
# Processing Record 486 of 700 | Ivano-Frankivsk
# Processing Record 487 of 700 | Vreed-en-Hoop
# Processing Record 488 of 700 | Janaúba
# Processing Record 489 of 700 | Santa Clara
# Processing Record 490 of 700 | Winfield
# Processing Record 491 of 700 | Covington
# Processing Record 492 of 700 | Novi Bečej
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 493 of 700 | Ridgeland
# Processing Record 494 of 700 | Lille
# Processing Record 495 of 700 | Kullorsuaq
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 496 of 700 | Čoka
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 497 of 700 | Shamattawa
# Processing Record 498 of 700 | Omuthiya
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 499 of 700 | Sweetwater
# Processing Record 500 of 700 | Njombe
# Processing Record 501 of 700 | Mounds View
# Processing Record 502 of 700 | Comendador
# Processing Record 503 of 700 | Guthrie
# Processing Record 504 of 700 | Kyzyl
# Processing Record 505 of 700 | Echternach
# Processing Record 506 of 700 | Calexico
# Processing Record 507 of 700 | Bartonville
# Processing Record 508 of 700 | Marib
# Processing Record 509 of 700 | Zalaegerszeg
# Processing Record 510 of 700 | Black Mountain
# Processing Record 511 of 700 | Ellenville
# Processing Record 512 of 700 | Springfield
# Processing Record 513 of 700 | Valenzuela
# Processing Record 514 of 700 | Pekin
# Processing Record 515 of 700 | Illichivsk
# Processing Record 516 of 700 | Osório
# Processing Record 517 of 700 | Garden City
# Processing Record 518 of 700 | Emerson
# Processing Record 519 of 700 | Fall River
# Processing Record 520 of 700 | Johannesburg
# Processing Record 521 of 700 | San Jose
# Processing Record 522 of 700 | Dutse
# Processing Record 523 of 700 | Muskego
# Processing Record 524 of 700 | Westwood
# Processing Record 525 of 700 | Penticton
# Processing Record 526 of 700 | Misratah
# Processing Record 527 of 700 | Codó
# Processing Record 528 of 700 | Altoona
# Processing Record 529 of 700 | Coquimbo
# Processing Record 530 of 700 | Virovitica
# Processing Record 531 of 700 | Aomori
# Processing Record 532 of 700 | Qala i Naw
# Processing Record 533 of 700 | Kropotkin
# Processing Record 534 of 700 | Aransas Pass
# Processing Record 535 of 700 | Grosuplje
# Processing Record 536 of 700 | Sîngerei
# Processing Record 537 of 700 | Kisii
# Processing Record 538 of 700 | Zagazig
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 539 of 700 | Coimbra
# Processing Record 540 of 700 | Glenview
# Processing Record 541 of 700 | Kingstree
# Processing Record 542 of 700 | Geneina
# Processing Record 543 of 700 | Tsu
# Processing Record 544 of 700 | Sholapur
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 545 of 700 | Kamina
# Processing Record 546 of 700 | Clayton
# Processing Record 547 of 700 | Vlasotince
# Processing Record 548 of 700 | Ipú
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 549 of 700 | Worcester
# Processing Record 550 of 700 | Berdyansk
# Processing Record 551 of 700 | Chascomús
# Processing Record 552 of 700 | Bhavnagar
# Processing Record 553 of 700 | Dinguiraye
# Processing Record 554 of 700 | Corozal
# Processing Record 555 of 700 | Topola
# Processing Record 556 of 700 | Kohat
# Processing Record 557 of 700 | Hove
# Processing Record 558 of 700 | Batticaloa
# Processing Record 559 of 700 | Port Lincoln
# Processing Record 560 of 700 | Collierville
# Processing Record 561 of 700 | Kaya
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 562 of 700 | South Bay
# Processing Record 563 of 700 | Buyant-Uhaa
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 564 of 700 | Zaria
# Processing Record 565 of 700 | Livonia
# Processing Record 566 of 700 | Koszalin
# Processing Record 567 of 700 | Piedmont
# Processing Record 568 of 700 | Urbana
# Processing Record 569 of 700 | Logan
# Processing Record 570 of 700 | Destrnik
# Processing Record 571 of 700 | Hania
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 572 of 700 | Grimes
# Processing Record 573 of 700 | Naftalan
# Processing Record 574 of 700 | Waltham
# Processing Record 575 of 700 | Motul
# Processing Record 576 of 700 | Itigi
# Processing Record 577 of 700 | Crystal City
# Processing Record 578 of 700 | Superior
# Processing Record 579 of 700 | Colonia del Sacramento
# Processing Record 580 of 700 | Bedford
# Processing Record 581 of 700 | Pembroke
# Processing Record 582 of 700 | Antsirabe
# Processing Record 583 of 700 | Rankin Inlet
# Processing Record 584 of 700 | Abomey
# Processing Record 585 of 700 | Vĩnh Yên
# Processing Record 586 of 700 | Mount Vernon
# Processing Record 587 of 700 | Windsor
# Processing Record 588 of 700 | Fillmore
# Processing Record 589 of 700 | Syktyvkar
# Processing Record 590 of 700 | Longyan
# Processing Record 591 of 700 | Rehoboth
# Processing Record 592 of 700 | Aurora
# Processing Record 593 of 700 | Racine
# Processing Record 594 of 700 | Pisa
# Processing Record 595 of 700 | São Mateus
# Processing Record 596 of 700 | Starkville
# Processing Record 597 of 700 | Bifoum
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 598 of 700 | Tsumeb
# Processing Record 599 of 700 | El Monte
# Processing Record 600 of 700 | Campo Grande
# Processing Record 601 of 700 | Kürdəmir
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 602 of 700 | Udine
# Processing Record 603 of 700 | Clairton
# Processing Record 604 of 700 | Eaton Rapids
# Processing Record 605 of 700 | Malishevë
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 606 of 700 | West Richland
# Processing Record 607 of 700 | Schaffhausen
# Processing Record 608 of 700 | George
# Processing Record 609 of 700 | Chabahar
# Processing Record 610 of 700 | Hollywood
# Processing Record 611 of 700 | Coronel Oviedo
# Processing Record 612 of 700 | La Esmeralda
# Processing Record 613 of 700 | Surgut
# Processing Record 614 of 700 | Marshfield
# Processing Record 615 of 700 | Craigavon
# Processing Record 616 of 700 | Broussard
# Processing Record 617 of 700 | El Calafate
# Processing Record 618 of 700 | Gatchina
# Processing Record 619 of 700 | Chicksands
# Processing Record 620 of 700 | Tatuí
# Processing Record 621 of 700 | Smithers
# Processing Record 622 of 700 | Tunduma
# Processing Record 623 of 700 | Kunming
# Processing Record 624 of 700 | Zahlé
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 625 of 700 | Trujillo
# Processing Record 626 of 700 | Nanjing
# Processing Record 627 of 700 | Star
# Processing Record 628 of 700 | Kasaji
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 629 of 700 | Padangpanjang
# Processing Record 630 of 700 | Guymon
# Processing Record 631 of 700 | Little Current
# Processing Record 632 of 700 | Al Fallujah
# Processing Record 633 of 700 | Queanbeyan
# Processing Record 634 of 700 | Cochrane
# Processing Record 635 of 700 | Linchuan
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 636 of 700 | Haysville
# Processing Record 637 of 700 | Baramula
# Processing Record 638 of 700 | Ukhta
# Processing Record 639 of 700 | Kennett
# Processing Record 640 of 700 | Piso Firme
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 641 of 700 | Amol
# Processing Record 642 of 700 | Kambove
# Processing Record 643 of 700 | Channel-Port aux Basques
# Processing Record 644 of 700 | Placetas
# Processing Record 645 of 700 | Kuacjok
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 646 of 700 | West Chester
# Processing Record 647 of 700 | Brest
# Processing Record 648 of 700 | Sadiqabad
# Processing Record 649 of 700 | Turnišče
# Processing Record 650 of 700 | Brooks
# Processing Record 651 of 700 | Oshawa
# Processing Record 652 of 700 | Hopatcong
# Processing Record 653 of 700 | Bulgan
# Processing Record 654 of 700 | Rockingham
# Processing Record 655 of 700 | Strongsville
# Processing Record 656 of 700 | Ovalle
# Processing Record 657 of 700 | Bordj Bou Arréridj
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 658 of 700 | Decorah
# Processing Record 659 of 700 | Al Kufrah
# Processing Record 660 of 700 | Porto Nacional
# Processing Record 661 of 700 | Wexford
# Processing Record 662 of 700 | Galesburg
# Processing Record 663 of 700 | Serang
# Processing Record 664 of 700 | Itacoatiara
# Processing Record 665 of 700 | Waynesboro
# Processing Record 666 of 700 | Ondjiva
# Processing Record 667 of 700 | Awasa
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 668 of 700 | Liaoyang
# Processing Record 669 of 700 | Maryland Heights
# Processing Record 670 of 700 | Mercer Island
# Processing Record 671 of 700 | Morioka
# Processing Record 672 of 700 | Jeonju
# Processing Record 673 of 700 | Pasto
# Processing Record 674 of 700 | Termiz
# Processing Record 675 of 700 | Shasta Lake
# Processing Record 676 of 700 | Nasik
# Processing Record 677 of 700 | Danbury
# Processing Record 678 of 700 | Troy
# Processing Record 679 of 700 | East Wenatchee
# Processing Record 680 of 700 | Amahai
# Processing Record 681 of 700 | Highland Park
# Processing Record 682 of 700 | Nida
# Processing Record 683 of 700 | Port Sudan
# Processing Record 684 of 700 | Chone
# Processing Record 685 of 700 | Reconquista
# Processing Record 686 of 700 | Mount Airy
# Processing Record 687 of 700 | Chicago
# Processing Record 688 of 700 | Danville
# Processing Record 689 of 700 | Kičevo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 690 of 700 | Tiruppur
# Processing Record 691 of 700 | Fonadhoo
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 692 of 700 | Olongapo
# Processing Record 693 of 700 | Probištip
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# key is missing
# Processing Record 694 of 700 | Tefé
# Processing Record 695 of 700 | Yirga Alem
# Processing Record 696 of 700 | Coos Bay
# Processing Record 697 of 700 | Smithfield
# Processing Record 698 of 700 | Gaoua
# Processing Record 699 of 700 | Santee
# Processing Record 700 of 700 | Rice Lake

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a dictionary from the raw data
raw_weather_data = {"City": name,
                   "Cloudiness": clouds,
                   "Date": date,
                   "Humidity": humidity,
                   "Max Temp": temp_max,
                   "Wind Speed": wind_speed}

#create a dataframe from the dictionary
weather_data = pd.DataFrame(raw_weather_data)

# %%
#create a dataframe from the dictionary
#weather_data = pd.DataFrame(raw_weather_data)

# %%
#merge the dataframe with the lats and longs with the dataframe with the weather information
city_weather_data = pd.merge(weather_data,random_cities, on="City")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f52fcfc684df> in <module>
#       1 #merge the dataframe with the lats and longs with the dataframe with the weather information
# ----> 2 city_weather_data = pd.merge(weather_data,random_cities, on="City")
#       3
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# --> 551          self.join_names) = self._get_merge_keys()
#     552
#     553         # validate the merge keys dtypes. We may need to coerce
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     855                             right_keys.append(
#     856                                 right._get_label_or_level_values(
# --> 857                                     rk, stacklevel=stacklevel))
#     858                         else:
#     859                             # work-around for merge_asof(right_index=True)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'City'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Max Temp"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Max Temperature ({now.month}/{now.day}/{now.year})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig('LatvsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Humidity"]
plt.xlim(-60,80)
plt.ylim(20,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Humidity ({now.month}/{now.day}/{now.year})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsHumid.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Cloudiness"]
plt.xlim(-60,80)
plt.ylim(0,100)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Cloudiness ({now.month}/{now.day}/{now.year})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig('LatvsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a scatterplot, label it and save it as a png file
x_axis = city_weather_data["Latitude"]
y_axis = city_weather_data["Wind Speed"]
plt.xlim(-60,80)
plt.ylim(0,30)
plt.scatter(x_axis,y_axis,marker="o")
plt.title(f"City Latitude vs. Wind Speed ({now.month}/{now.day}/{now.year})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.savefig('LatvsWind.png')
plt.show()
